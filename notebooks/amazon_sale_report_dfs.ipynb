# %%
import pandas as pd
import numpy as np

# %%
df_amazon_sr = pd.read_csv(
    '../data/raw_csv_files/Amazon Sale Report.csv', low_memory=False)

# %%
df_amazon_sr.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# 0            Set  ...      INR  647.62       MUMBAI  MAHARASHTRA
# 1          kurta  ...      INR  406.00    BENGALURU    KARNATAKA
# 2          kurta  ...      INR  329.00  NAVI MUMBAI  MAHARASHTRA
# 3  Western Dress  ...      INR  753.33   PUDUCHERRY   PUDUCHERRY
# 4            Top  ...      INR  574.00      CHENNAI   TAMIL NADU
#
#   ship-postal-code  ship-country  \
# 0         400081.0            IN
# 1         560085.0            IN
# 2         410210.0            IN
# 3         605008.0            IN
# 4         600073.0            IN
#
#                                        promotion-ids    B2B  fulfilled-by  \
# 0                                                NaN  False     Easy Ship
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True           NaN
# 3                                                NaN  False     Easy Ship
# 4                                                NaN  False           NaN
#
#   Unnamed: 22
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 24 columns]

# %%
# Format columns
df_amazon_sr.columns = (
    df_amazon_sr.columns
    .str.strip()                                # Remove leading/trailing whitespace
    .str.lower()                                # Convert to lowercase
    .str.replace(r'[^\w\s]', '', regex=True)    # Remove special characters like - or .
    .str.replace(r'\s+', '_', regex=True)       # Replace spaces with underscores
)

# %%
df_amazon_sr.nunique()
# Out:
# index               128975
# order_id            120378
# date                    91
# status                  13
# fulfilment               2
# sales_channel            2
# shipservicelevel         2
# style                 1377
# sku                   7195
# category                 9
# size                    11
# asin                  7190
# courier_status           3
# qty                     10
# currency                 1
# amount                1410
# shipcity              8955
# shipstate               69
# shippostalcode        9459
# shipcountry              1
# promotionids          5787
# b2b                      2
# fulfilledby              1
# unnamed_22               1
# dtype: int64

# %%
# Drop unnecessary columns
cols_to_drop = [
    'index',
    'asin',
    'shipcountry',
    'unnamed_22'
]
df_amazon_sr.drop(columns=cols_to_drop, inplace=True)

# %%
df_amazon_sr['sales_channel'].value_counts()
# Out:
# sales_channel
# Amazon.in     128851
# Non-Amazon       124
# Name: count, dtype: int64

# %%
# Drop 124 rows from non-Amazon sales_channel (all unshipped, not relevant)
df_amazon_sr = df_amazon_sr[df_amazon_sr['sales_channel'] == 'Amazon.in']

# %%
# Drop 'sales_channel' now that it's uniform

# Filter and make a safe copy
df_amazon_sr = df_amazon_sr[df_amazon_sr['sales_channel'] == 'Amazon.in'].copy()

# Now it's safe to drop the column
df_amazon_sr.drop(columns=['sales_channel'], inplace=True)

# %%
df_amazon_sr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128851 entries, 0 to 128974
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   order_id          128851 non-null  object
#  1   date              128851 non-null  object
#  2   status            128851 non-null  object
#  3   fulfilment        128851 non-null  object
#  4   shipservicelevel  128851 non-null  object
#  5   style             128851 non-null  object
#  6   sku               128851 non-null  object
#  7   category          128851 non-null  object
#  8   size              128851 non-null  object
#  9   courier_status    121979 non-null  object
#  10  qty               128851 non-null  int64
#  11  currency          121180 non-null  object
#  12  amount            121180 non-null  float64
#  13  shipcity          128818 non-null  object
#  14  shipstate         128818 non-null  object
#  15  shippostalcode    128818 non-null  float64
#  16  promotionids      79822 non-null   object
#  17  b2b               128851 non-null  bool
#  18  fulfilledby       39277 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(15)
# memory usage: 18.8+ MB

# %%
# Convert some data types

# %%
# Convert date to datetime64
df_amazon_sr['date'] = pd.to_datetime(
    df_amazon_sr['date'],
    format='%m-%d-%y',     # Specify expected format
    errors='coerce'        # Handle bad entries safely
)
print(df_amazon_sr['date'].dtypes)
# Out:
# datetime64[ns]

# %%
# Convert postal codes to strings so we don't lose any formatting (like leading zeros)
df_amazon_sr['shippostalcode'] = (
    df_amazon_sr['shippostalcode']
    .astype('Int64')   # keep nulls intact
    .astype(str)
)

# %%
# Confirm
print(df_amazon_sr[['date', 'shippostalcode']].dtypes)
# Out:
# date              datetime64[ns]
# shippostalcode            object
# dtype: object

# %%
# Show date rage of data
print('Date Range:')
print('Min:', df_amazon_sr['date'].min())
print('Max:', df_amazon_sr['date'].max())
# Out:
# Date Range:
# Min: 2022-03-31 00:00:00
# Max: 2022-06-29 00:00:00

# %%
# In India, Q1 FY23 = April 1, 2022 to June 30, 2022
# The original data starts on March 31 and ends on June 29 — likely due to time zone differences or US-based reporting
# Shift all dates forward by one day to align cleanly with Indian fiscal Q1 FY23

# %%
df_amazon_sr['date'] = df_amazon_sr['date'] + pd.Timedelta(days=1)

# %%
# Show date rage of data
print('Date Range:')
print('Min:', df_amazon_sr['date'].min())
print('Max:', df_amazon_sr['date'].max())
# Out:
# Date Range:
# Min: 2022-04-01 00:00:00
# Max: 2022-06-30 00:00:00

# %%
# Order the dataframe by date
df_amazon_sr = df_amazon_sr.sort_values(by='date').reset_index(drop=True)

# %%
df_amazon_sr.describe()
# Out:
#                                 date            qty         amount
# count                         128851  128851.000000  121180.000000
# mean   2022-05-13 11:51:46.145858304       0.904005     648.561465
# min              2022-04-01 00:00:00       0.000000       0.000000
# 25%              2022-04-21 00:00:00       1.000000     449.000000
# 50%              2022-05-11 00:00:00       1.000000     605.000000
# 75%              2022-06-05 00:00:00       1.000000     788.000000
# max              2022-06-30 00:00:00       8.000000    5584.000000
# std                              NaN       0.308131     281.211687

# %%
# Rename some columns for claity
df_amazon_sr.rename(columns={
    'shipcity': 'city',
    'shipstate': 'state',
    'shippostalcode': 'postal_code',
    'shipservicelevel': 'shipping_method',
    'promotionids': 'promo_id',
    'fulfilledby': 'fulfilled_by'
}, inplace=True)

# %%
# Format Title Case for category values (consistency) & remove any white spaces
df_amazon_sr['category'] = df_amazon_sr['category'].str.strip().str.title()

# %%
# Re-eheck unique promo_ids
df_amazon_sr['promo_id'].nunique()
# Out:
# 5787

# %%
# Looks very messy
df_amazon_sr['promo_id'].dropna().unique()[:10]
# Out:
# array(['Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-SL3Y2YRMAUNFC,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-XXRCW6NZEPZI4,Amazon PLCC Free-Financing Universal Merchant AAT-WSJLDN3X7KEMO,Amazon PLCC Free-Financing Universal Merchant AAT-VL6FGQVGQVXUS,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,Amazon PLCC Free-Financing Universal Merchant AAT-ZYL5UPUNW6T62,Amazon PLCC Free-Financing Universal Merchant AAT-G5ZRX4BZOIODU,Amazon PLCC Free-Financing Universal Merchant AAT-ACZIPIA37BFIY,Amazon PLCC Free-Financing Universal Merchant AAT-YFJA6XMAMWZSK,Amazon PLCC Free-Financing Universal Merchant AAT-K66BSCE2J2V5E,Amazon PLCC Free-Financing Universal Merchant AAT-DFM4OAAQ3RGPM,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4',
#        'IN Core Free Shipping 2015/04/08 23-48-5-108',
#        'Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-XXRCW6NZEPZI4,Amazon PLCC Free-Financing Universal Merchant AAT-R7GXNZWISTRFA,Amazon PLCC Free-Financing Universal Merchant AAT-WSJLDN3X7KEMO,Amazon PLCC Free-Financing Universal Merchant AAT-VL6FGQVGQVXUS,Amazon PLCC Free-Financing Universal Merchant AAT-3NV3MZDDJ5LUA,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,VPC-44571-38707597 Coupon,Amazon PLCC Free-Financing Universal Merchant AAT-ZYL5UPUNW6T62,Amazon PLCC Free-Financing Universal Merchant AAT-G5ZRX4BZOIODU,Amazon PLCC Free-Financing Universal Merchant AAT-P3CSUAK4HTEP2,Amazon PLCC Free-Financing Universal Merchant AAT-ACZIPIA37BFIY,Amazon PLCC Free-Financing Universal Merchant AAT-YFJA6XMAMWZSK,Amazon PLCC Free-Financing Universal Merchant AAT-K66BSCE2J2V5E,Amazon PLCC Free-Financing Universal Merchant AAT-DFM4OAAQ3RGPM,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4',
#        'Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-SL3Y2YRMAUNFC,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-XXRCW6NZEPZI4,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,Amazon PLCC Free-Financing Universal Merchant AAT-ZYL5UPUNW6T62,Amazon PLCC Free-Financing Universal Merchant AAT-G5ZRX4BZOIODU,Amazon PLCC Free-Financing Universal Merchant AAT-YFJA6XMAMWZSK,Amazon PLCC Free-Financing Universal Merchant AAT-K66BSCE2J2V5E,Amazon PLCC Free-Financing Universal Merchant AAT-DFM4OAAQ3RGPM,Amazon PLCC Free-Financing Universal Merchant AAT-TNYBHEAO7HOHO,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4,Amazon PLCC Free-Financing Universal Merchant AAT-QMFZ3M7T5NPDS,Amazon PLCC Free-Financing Universal Merchant #MP-pmilan-1601980554292',
#        'Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-SL3Y2YRMAUNFC,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-XXRCW6NZEPZI4,Amazon PLCC Free-Financing Universal Merchant AAT-WSJLDN3X7KEMO,Amazon PLCC Free-Financing Universal Merchant AAT-VL6FGQVGQVXUS,Amazon PLCC Free-Financing Universal Merchant AAT-3NV3MZDDJ5LUA,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,Amazon PLCC Free-Financing Universal Merchant AAT-5IRDV7W2ZQLXW,Amazon PLCC Free-Financing Universal Merchant AAT-ZYL5UPUNW6T62,Amazon PLCC Free-Financing Universal Merchant AAT-G5ZRX4BZOIODU,Amazon PLCC Free-Financing Universal Merchant AAT-ACZIPIA37BFIY,Amazon PLCC Free-Financing Universal Merchant AAT-YFJA6XMAMWZSK,Amazon PLCC Free-Financing Universal Merchant AAT-K66BSCE2J2V5E,Amazon PLCC Free-Financing Universal Merchant AAT-DFM4OAAQ3RGPM,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4',
#        'Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-XXRCW6NZEPZI4,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,Amazon PLCC Free-Financing Universal Merchant AAT-ZYL5UPUNW6T62,Amazon PLCC Free-Financing Universal Merchant AAT-G5ZRX4BZOIODU,Amazon PLCC Free-Financing Universal Merchant AAT-YFJA6XMAMWZSK,Amazon PLCC Free-Financing Universal Merchant AAT-K66BSCE2J2V5E,Amazon PLCC Free-Financing Universal Merchant AAT-DFM4OAAQ3RGPM,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4',
#        'Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-XXRCW6NZEPZI4,Amazon PLCC Free-Financing Universal Merchant AAT-WSJLDN3X7KEMO,Amazon PLCC Free-Financing Universal Merchant AAT-VL6FGQVGQVXUS,Amazon PLCC Free-Financing Universal Merchant AAT-3NV3MZDDJ5LUA,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,Amazon PLCC Free-Financing Universal Merchant AAT-ZYL5UPUNW6T62,Amazon PLCC Free-Financing Universal Merchant AAT-G5ZRX4BZOIODU,Amazon PLCC Free-Financing Universal Merchant AAT-ACZIPIA37BFIY,Amazon PLCC Free-Financing Universal Merchant AAT-YFJA6XMAMWZSK,Amazon PLCC Free-Financing Universal Merchant AAT-K66BSCE2J2V5E,Amazon PLCC Free-Financing Universal Merchant AAT-DFM4OAAQ3RGPM,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4',
#        'Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-SL3Y2YRMAUNFC,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-XXRCW6NZEPZI4,Amazon PLCC Free-Financing Universal Merchant AAT-R7GXNZWISTRFA,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,Amazon PLCC Free-Financing Universal Merchant AAT-ZYL5UPUNW6T62,Amazon PLCC Free-Financing Universal Merchant AAT-G5ZRX4BZOIODU,Amazon PLCC Free-Financing Universal Merchant AAT-P3CSUAK4HTEP2,Amazon PLCC Free-Financing Universal Merchant AAT-YFJA6XMAMWZSK,Amazon PLCC Free-Financing Universal Merchant AAT-K66BSCE2J2V5E,Amazon PLCC Free-Financing Universal Merchant AAT-DFM4OAAQ3RGPM,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4',
#        'Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-XXRCW6NZEPZI4,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,Amazon PLCC Free-Financing Universal Merchant AAT-ZYL5UPUNW6T62,Amazon PLCC Free-Financing Universal Merchant AAT-G5ZRX4BZOIODU,Amazon PLCC Free-Financing Universal Merchant AAT-YFJA6XMAMWZSK,Amazon PLCC Free-Financing Universal Merchant AAT-K66BSCE2J2V5E,Amazon PLCC Free-Financing Universal Merchant AAT-DFM4OAAQ3RGPM,Amazon PLCC Free-Financing Universal Merchant AAT-TNYBHEAO7HOHO,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4,Amazon PLCC Free-Financing Universal Merchant AAT-QMFZ3M7T5NPDS,Amazon PLCC Free-Financing Universal Merchant #MP-pmilan-1601980554292',
#        'Duplicated AYTJSBA8ZOP16 1567159860988'], dtype=object)

# %%
# Cut out everything after 'Free-Financing' (it's meaningless) and assign to new column
df_amazon_sr['promo_group'] = df_amazon_sr['promo_id'].str.extract(r'^(.*?Free-Financing)')

# %%
# Fill in all NaNs in promo_group with 'None'
df_amazon_sr['promo_group'] = df_amazon_sr['promo_group'].fillna('None')

# %%
# Check value counts
df_amazon_sr['promo_group'].value_counts()
# Out:
# promo_group
# None                          96503
# Amazon PLCC Free-Financing    32348
# Name: count, dtype: int64

# %%
# Check number of uniques 
df_amazon_sr['promo_group'].nunique()
# 5787 -> 2
# Out:
# 2

# %%
# Drop the original, messy 'promo_id' column
df_amazon_sr.drop(columns=['promo_id'], inplace=True)

# %%
# Get original column name back; rename 'promo_group' to 'promo_id'
df_amazon_sr.rename(columns={'promo_group': 'promo_id'}, inplace=True)

# %%
# Fill in all NaNs in fulfilled_by with 'Other'
df_amazon_sr['fulfilled_by'] = df_amazon_sr['fulfilled_by'].fillna('Other')

# %%
# Clean up 'city' & 'state' columns now

# %%
# First, format city & state columns to have same Title Case, strip away white space
df_amazon_sr['city'] = df_amazon_sr['city'].str.strip().str.title()
df_amazon_sr['state'] = df_amazon_sr['state'].str.strip().str.title()

# %%
# Start with 'state'
df_amazon_sr['state'].nunique()
# Out:
# 47

# %%
# View list of unique values
sorted(df_amazon_sr['state'].dropna().unique().tolist())
# Out:
# ['Andaman & Nicobar',
#  'Andhra Pradesh',
#  'Apo',
#  'Ar',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Dadra And Nagar',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Ladakh',
#  'Lakshadweep',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'New Delhi',
#  'Nl',
#  'Odisha',
#  'Orissa',
#  'Pb',
#  'Pondicherry',
#  'Puducherry',
#  'Punjab',
#  'Punjab/Mohali/Zirakpur',
#  'Rajasthan',
#  'Rajshthan',
#  'Rajsthan',
#  'Rj',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal']

# %%
# Standardize common spelling errors and abbreviations in 'state'
state_corrections = {
    'Rajshthan': 'Rajasthan',
    'Rajsthan': 'Rajasthan',
    'Rj': 'Rajasthan',
    'Orissa': 'Odisha',                                             # Official state name
    'Pondicherry': 'Puducherry',
    'Pb': 'Punjab',
    'Punjab/Mohali/Zirakpur': 'Punjab',                             # Keep only state
    'New Delhi': 'Delhi',                                           # Normalize NCR variant
    'Nl': 'Nagaland',
    'Ar': 'Arunachal Pradesh',
    'Apo': None,                                                    # Likely invalid
    'Dadra And Nagar': 'Dadra And Nagar Haveli And Daman And Diu'   # Official UT name
}
df_amazon_sr['state'] = df_amazon_sr['state'].replace(state_corrections)

# %%
df_amazon_sr['state'].nunique()
# Out:
# 36

# %%
df_amazon_sr['state'].isnull().sum()
# Out:
# np.int64(34)

# %%
df_amazon_sr[df_amazon_sr['state'].isnull()]
# Out:
#                    order_id       date                        status  \
# 4564    405-0034289-0259545 2022-04-04                     Cancelled
# 12181   407-3064376-9158743 2022-04-09                     Cancelled
# 12182   407-3064376-9158743 2022-04-09                     Cancelled
# 17721   404-7506843-7913132 2022-04-13  Shipped - Delivered to Buyer
# 23410   406-4079063-8291520 2022-04-16                     Cancelled
# 24952   402-8628677-0457954 2022-04-17  Shipped - Returned to Seller
# 29561   405-4927647-8064368 2022-04-20                       Shipped
# 31484   402-4919636-4333150 2022-04-21  Shipped - Delivered to Buyer
# 33945   404-9229894-8608305 2022-04-22                       Shipped
# 34774   407-4532637-8415521 2022-04-23                     Cancelled
# 37060   402-0107720-7057168 2022-04-24                       Shipped
# 40844   406-4003386-8768363 2022-04-26                       Shipped
# 46142   404-0566904-4825137 2022-04-30                       Shipped
# 46161   404-0566904-4825137 2022-04-30                       Shipped
# 55493   405-8605864-8021901 2022-05-05  Shipped - Returned to Seller
# 56243   402-8651786-0683548 2022-05-05                       Shipped
# 59172   171-4691098-8489159 2022-05-07  Shipped - Delivered to Buyer
# 60939   403-2857451-7335536 2022-05-08                       Shipped
# 61015   171-4552355-0255565 2022-05-08  Shipped - Returned to Seller
# 65541   405-3420451-5230744 2022-05-12                     Cancelled
# 65715   405-1356730-8598722 2022-05-12  Shipped - Delivered to Buyer
# 65932   407-4664354-2179554 2022-05-12                       Shipped
# 65994   406-7680604-5439529 2022-05-12                       Shipped
# 65995   406-7680604-5439529 2022-05-12                       Shipped
# 76391   402-1049475-3611523 2022-05-21                       Shipped
# 78666   171-3257610-9237139 2022-05-23  Shipped - Delivered to Buyer
# 92958   403-4249038-6582716 2022-06-03  Shipped - Delivered to Buyer
# 95188   403-5172380-9787567 2022-06-04                       Shipped
# 96330   405-5884153-9925116 2022-06-05                       Shipped
# 96420   405-5884153-9925116 2022-06-05                       Shipped
# 96535   405-5884153-9925116 2022-06-05                       Shipped
# 96705   405-0340492-2359532 2022-06-05                     Cancelled
# 113032  402-8673941-7883531 2022-06-17                     Cancelled
# 116321  403-3190636-2013146 2022-06-19  Shipped - Delivered to Buyer
#
#        fulfilment shipping_method     style                       sku  \
# 4564       Amazon       Expedited     J0077               J0077-SKD-S
# 12181    Merchant        Standard   JNE3405              JNE3405-KR-S
# 12182    Merchant        Standard   JNE3567              JNE3567-KR-M
# 17721    Merchant        Standard    SET350            SET350-KR-NP-L
# 23410      Amazon       Expedited   JNE3567            JNE3567-KR-XXL
# 24952    Merchant        Standard     J0003               J0003-SET-S
# 29561      Amazon       Expedited     J0230              J0230-SKD-XS
# 31484    Merchant        Standard   JNE1233  JNE1233-BLUE-KR-031-XXXL
# 33945      Amazon       Expedited   JNE3510              JNE3510-KR-M
# 34774    Merchant        Standard   JNE3405              JNE3405-KR-S
# 37060      Amazon       Expedited     J0003               J0003-SET-S
# 40844      Amazon       Expedited   JNE3376              JNE3376-KR-M
# 46142      Amazon       Expedited   JNE3697              JNE3697-KR-L
# 46161      Amazon       Expedited     J0301                J0301-TP-L
# 55493    Merchant        Standard   JNE1951        JNE1951-KR-155-XXL
# 56243      Amazon       Expedited   JNE3690             JNE3690-TU-XL
# 59172    Merchant        Standard    SET183            SET183-KR-DH-M
# 60939      Amazon       Expedited   JNE3510              JNE3510-KR-S
# 61015    Merchant        Standard    SET324           SET324-KR-NP-XL
# 65541      Amazon       Expedited    SET374            SET374-KR-NP-M
# 65715    Merchant        Standard    SET187           SET187-KR-DH-XL
# 65932      Amazon       Expedited    SET374            SET374-KR-NP-M
# 65994      Amazon       Expedited  PJNE3607           PJNE3607-KR-4XL
# 65995      Amazon       Expedited  PJNE3368           PJNE3368-KR-4XL
# 76391      Amazon       Expedited   JNE3739            JNE3739-KR-XXL
# 78666    Merchant        Standard   JNE3365       JNE3365-KR-1052-A-L
# 92958    Merchant        Standard   JNE3797              JNE3797-KR-M
# 95188      Amazon       Expedited   JNE3366         JNE3366-KR-1053-L
# 96330      Amazon       Expedited    SET154            SET154-KR-NP-L
# 96420      Amazon       Expedited    SET337            SET337-KR-NP-L
# 96535      Amazon       Expedited   JNE3697              JNE3697-KR-L
# 96705      Amazon       Expedited   JNE3465              JNE3465-KR-L
# 113032     Amazon       Expedited   JNE3734             JNE3734-KR-XL
# 116321   Merchant        Standard     J0351               J0351-SET-S
#
#              category size courier_status  qty currency  amount city state  \
# 4564              Set    S      Cancelled    0      NaN     NaN  Apo  None
# 12181           Kurta    S            NaN    0      INR   380.0  NaN   NaN
# 12182           Kurta    M            NaN    0      INR   380.0  NaN   NaN
# 17721             Set    L        Shipped    1      INR  1299.0  NaN   NaN
# 23410           Kurta  XXL      Unshipped    1      INR   399.0  NaN   NaN
# 24952             Set    S        Shipped    1      INR   654.0  NaN   NaN
# 29561             Set   XS        Shipped    1      INR  1112.0  NaN   NaN
# 31484           Kurta  3XL        Shipped    1      INR   376.0  NaN   NaN
# 33945           Kurta    M        Shipped    1      INR   442.0  NaN   NaN
# 34774           Kurta    S            NaN    0      INR   380.0  NaN   NaN
# 37060             Set    S        Shipped    1      INR   654.0  NaN   NaN
# 40844           Kurta    M        Shipped    1      INR   432.0  NaN   NaN
# 46142           Kurta    L        Shipped    1      INR   458.0  NaN   NaN
# 46161             Top    L        Shipped    1      INR   493.0  NaN   NaN
# 55493           Kurta  XXL        Shipped    1      INR   368.0  NaN   NaN
# 56243             Top   XL        Shipped    1      INR   487.0  NaN   NaN
# 59172             Set    M        Shipped    1      INR   759.0  NaN   NaN
# 60939           Kurta    S        Shipped    1      INR   467.0  NaN   NaN
# 61015             Set   XL        Shipped    1      INR   607.0  NaN   NaN
# 65541             Set    M      Cancelled    0      NaN     NaN  NaN   NaN
# 65715             Set   XL        Shipped    1      INR   699.0  NaN   NaN
# 65932             Set    M        Shipped    1      INR   666.0  NaN   NaN
# 65994           Kurta  4XL        Shipped    1      INR   869.0  NaN   NaN
# 65995           Kurta  4XL        Shipped    1      INR   869.0  NaN   NaN
# 76391           Kurta  XXL        Shipped    1      INR   459.0  NaN   NaN
# 78666           Kurta    L        Shipped    1      INR   376.0  NaN   NaN
# 92958   Western Dress    M        Shipped    1      INR   735.0  NaN   NaN
# 95188           Kurta    L        Shipped    1      INR   376.0  NaN   NaN
# 96330             Set    L        Shipped    1      INR   832.0  NaN   NaN
# 96420             Set    L        Shipped    1      INR   874.0  NaN   NaN
# 96535           Kurta    L        Shipped    1      INR   486.0  NaN   NaN
# 96705           Kurta    L      Unshipped    1      INR   491.0  NaN   NaN
# 113032          Kurta   XL      Cancelled    0      NaN     NaN  NaN   NaN
# 116321            Set    S        Shipped    1      INR   792.0  NaN   NaN
#
#        postal_code    b2b fulfilled_by                    promo_id
# 4564        959121  False        Other                        None
# 12181         <NA>  False    Easy Ship                        None
# 12182         <NA>  False    Easy Ship                        None
# 17721         <NA>  False    Easy Ship  Amazon PLCC Free-Financing
# 23410         <NA>  False        Other                        None
# 24952         <NA>  False    Easy Ship  Amazon PLCC Free-Financing
# 29561         <NA>  False        Other                        None
# 31484         <NA>  False    Easy Ship  Amazon PLCC Free-Financing
# 33945         <NA>  False        Other                        None
# 34774         <NA>  False    Easy Ship                        None
# 37060         <NA>  False        Other                        None
# 40844         <NA>  False        Other                        None
# 46142         <NA>  False        Other                        None
# 46161         <NA>  False        Other                        None
# 55493         <NA>  False    Easy Ship  Amazon PLCC Free-Financing
# 56243         <NA>  False        Other                        None
# 59172         <NA>  False    Easy Ship  Amazon PLCC Free-Financing
# 60939         <NA>  False        Other                        None
# 61015         <NA>  False    Easy Ship  Amazon PLCC Free-Financing
# 65541         <NA>  False        Other                        None
# 65715         <NA>  False    Easy Ship  Amazon PLCC Free-Financing
# 65932         <NA>  False        Other                        None
# 65994         <NA>  False        Other                        None
# 65995         <NA>  False        Other                        None
# 76391         <NA>  False        Other                        None
# 78666         <NA>  False    Easy Ship  Amazon PLCC Free-Financing
# 92958         <NA>  False    Easy Ship  Amazon PLCC Free-Financing
# 95188         <NA>  False        Other                        None
# 96330         <NA>  False        Other                        None
# 96420         <NA>  False        Other                        None
# 96535         <NA>  False        Other                        None
# 96705         <NA>  False        Other                        None
# 113032        <NA>  False        Other                        None
# 116321        <NA>  False    Easy Ship  Amazon PLCC Free-Financing

# %%
# Dropped 34 rows missing both 'city' and 'state' — can't be used for location analysis
df_amazon_sr = df_amazon_sr[~(df_amazon_sr['state'].isnull() & df_amazon_sr['city'].isnull())]

# %%
# Check
sorted(df_amazon_sr['state'].dropna().unique().tolist())
# Out:
# ['Andaman & Nicobar',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Dadra And Nagar Haveli And Daman And Diu',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Ladakh',
#  'Lakshadweep',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal']

# %%
# Final Check
sorted(df_amazon_sr['state'].dropna().unique().tolist())
# Out:
# ['Andaman & Nicobar',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Dadra And Nagar Haveli And Daman And Diu',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Ladakh',
#  'Lakshadweep',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal']

# %%
# Now 'city'
df_amazon_sr['city'].nunique()
# Out:
# 7297

# %%
df_amazon_sr['postal_code'].nunique()
# Out:
# 9459

# %%
lookup_postal = (
    df_amazon_sr[['postal_code', 'state', 'city']]
    .drop_duplicates()
    .reset_index(drop=True)
)

# %%
lookup_postal.shape
# Out:
# (14436, 3)

# %%
lookup_postal.head()
# Out:
#   postal_code        state             city
# 0      700124  West Bengal          Kolkata
# 1      560090    Karnataka        Bengaluru
# 2      122001      Haryana          Gurgaon
# 3      401209  Maharashtra  Nalasopara East
# 4      500024    Telangana        Hyderabad

# %%
# Read the file (GeoNames, tab-separated, no header)
geo_postal = pd.read_csv(
    '../data/geonames_india.txt',   # ← update this path
    sep='\t',
    header=None,
    dtype={1: str}  # ensure postal_code keeps leading zeros
)

# %%
geo_postal.head()
# Out:
#    0       1           2                          3   4        5      6   \
# 0  IN  744301       Sawai  Andaman & Nicobar Islands   1  Nicobar  638.0
# 1  IN  744301      Kakana  Andaman & Nicobar Islands   1  Nicobar  638.0
# 2  IN  744301         Mus  Andaman & Nicobar Islands   1  Nicobar  638.0
# 3  IN  744301     Lapathy  Andaman & Nicobar Islands   1  Nicobar  638.0
# 4  IN  744301  Carnicobar  Andaman & Nicobar Islands   1  Nicobar  638.0
#
#            7   8       9        10  11
# 0  Carnicobar NaN  7.5166  93.6031   4
# 1  Carnicobar NaN  9.1167  92.8000   4
# 2  Carnicobar NaN  9.2333  92.7833   4
# 3  Carnicobar NaN  9.1833  92.7667   3
# 4  Carnicobar NaN  9.1833  92.7667   3

# %%
# Assign column names (from the GeoNames readme.txt file)
geo_postal.columns = [
    'country_code', 'postal_code', 'place_name', 'admin_name1', 'admin_code1',
    'admin_name2', 'admin_code2', 'admin_name3', 'admin_code3',
    'latitude', 'longitude', 'accuracy'
]

# %%
geo_postal.head()
# Out:
#   country_code postal_code  place_name                admin_name1  \
# 0           IN      744301       Sawai  Andaman & Nicobar Islands
# 1           IN      744301      Kakana  Andaman & Nicobar Islands
# 2           IN      744301         Mus  Andaman & Nicobar Islands
# 3           IN      744301     Lapathy  Andaman & Nicobar Islands
# 4           IN      744301  Carnicobar  Andaman & Nicobar Islands
#
#    admin_code1 admin_name2  admin_code2 admin_name3  admin_code3  latitude  \
# 0            1     Nicobar        638.0  Carnicobar          NaN    7.5166
# 1            1     Nicobar        638.0  Carnicobar          NaN    9.1167
# 2            1     Nicobar        638.0  Carnicobar          NaN    9.2333
# 3            1     Nicobar        638.0  Carnicobar          NaN    9.1833
# 4            1     Nicobar        638.0  Carnicobar          NaN    9.1833
#
#    longitude  accuracy
# 0    93.6031         4
# 1    92.8000         4
# 2    92.7833         4
# 3    92.7667         3
# 4    92.7667         3

# %%
geo_postal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155570 entries, 0 to 155569
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   country_code  155570 non-null  object
#  1   postal_code   155570 non-null  object
#  2   place_name    155569 non-null  object
#  3   admin_name1   155570 non-null  object
#  4   admin_code1   155570 non-null  int64
#  5   admin_name2   155570 non-null  object
#  6   admin_code2   153257 non-null  float64
#  7   admin_name3   147534 non-null  object
#  8   admin_code3   0 non-null       float64
#  9   latitude      155570 non-null  float64
#  10  longitude     155570 non-null  float64
#  11  accuracy      155570 non-null  int64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 14.2+ MB

# %%
# Filter only rows with valid lat/lon and place_name
geo_filtered = geo_postal[
    geo_postal['place_name'].notnull() &
    geo_postal['latitude'].notnull() &
    geo_postal['longitude'].notnull()
].copy()

# Keep best (lowest) accuracy row for each (postal_code, admin_name1)
geo_grouped = (
    geo_filtered.sort_values(by='accuracy')
    .groupby(['postal_code', 'admin_name1'], as_index=False)
    .first()
)
# Rename columns for merge compatibility
geo_grouped.rename(columns={
    'place_name': 'city_geo',
    'admin_name1': 'state'
}, inplace=True)

# %%
# Let's see if GeoNames format of the state values is = to ours
set(geo_grouped['state'].unique()) == set(df_amazon_sr['state'].unique())
# Out:
# False

# %%
set(df_amazon_sr['state'].unique()) - set(geo_grouped['state'].unique())
# Out:
# {'Andaman & Nicobar',
#  'Chhattisgarh',
#  'Dadra And Nagar Haveli And Daman And Diu',
#  'Ladakh',
#  None,
#  'Puducherry'}

# %%
# Match Amazon state names to GeoNames format
amazon_state_corrections = {
    'Andaman & Nicobar': 'Andaman & Nicobar Islands',
    'Chhattisgarh': 'Chattisgarh',
    'Dadra And Nagar Haveli And Daman And Diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'Ladakh': 'Jammu & Kashmir',
    'Puducherry': 'Pondicherry'
}
df_amazon_sr['state'] = df_amazon_sr['state'].replace(amazon_state_corrections)

# %%
# Merge enriched city and coordinates into main DataFrame
df_amazon_sr = df_amazon_sr.merge(
    geo_grouped[['postal_code', 'state', 'city_geo', 'latitude', 'longitude']],
    on=['postal_code', 'state'],
    how='left'
)

# %%
# Let's see if GeoNames format of the state values is now = to ours
set(geo_grouped['state'].unique()) == set(df_amazon_sr['state'].unique())
# Out:
# False

# %%
# It checks out, only value is 'None' which geo_grouped does not have
set(df_amazon_sr['state'].unique()) - set(geo_grouped['state'].unique())
# Out:
# {None}

# %%
# Compare cleaned 'city' to enriched 'city_geo'
df_amazon_sr['city_match'] = (
    df_amazon_sr['city'] == df_amazon_sr['city_geo']
)

# Check match counts
df_amazon_sr['city_match'].value_counts()
# Out:
# city_match
# False    128118
# True        700
# Name: count, dtype: int64

# %%
df_amazon_sr.head()
# Out:
#               order_id       date                        status fulfilment  \
# 0  404-1445673-1345134 2022-04-01  Shipped - Delivered to Buyer   Merchant
# 1  406-7387241-2881923 2022-04-01                       Shipped     Amazon
# 2  402-9332104-0945115 2022-04-01                     Cancelled   Merchant
# 3  408-1008226-2450750 2022-04-01                       Shipped     Amazon
# 4  403-4108307-0229121 2022-04-01                       Shipped     Amazon
#
#   shipping_method    style              sku category size courier_status  ...  \
# 0        Standard  JNE3724     JNE3724-KR-L    Kurta    L        Shipped  ...
# 1       Expedited   SET187  SET187-KR-DH-XL      Set   XL        Shipped  ...
# 2        Standard  JNE3383   JNE3383-KR-A-M    Kurta    M            NaN  ...
# 3       Expedited  JNE3405     JNE3405-KR-L    Kurta    L        Shipped  ...
# 4       Expedited   SET044   SET044-KR-NP-L      Set    L        Shipped  ...
#
#               city        state  postal_code    b2b fulfilled_by  \
# 0          Kolkata  West Bengal       700124  False    Easy Ship
# 1        Bengaluru    Karnataka       560090  False        Other
# 2          Gurgaon      Haryana       122001  False    Easy Ship
# 3  Nalasopara East  Maharashtra       401209  False        Other
# 4        Hyderabad    Telangana       500024  False        Other
#
#                      promo_id        city_geo latitude longitude city_match
# 0  Amazon PLCC Free-Financing     Barasat H.O  22.4656   88.7803      False
# 1                        None  Chikkabanavara  13.2257   77.5750      False
# 2                        None      Basai Road  28.4180   76.9839      False
# 3                        None   Nallosapare E  19.3600   73.3279      False
# 4                        None          Sahifa  17.4171   78.4772      False
#
# [5 rows x 23 columns]

# %%
# Use city_geo if available, fallback to original city if not
df_amazon_sr['city_final'] = df_amazon_sr['city_geo'].fillna(df_amazon_sr['city'])

# %%
df_amazon_sr.drop(columns=['city_geo', 'city_match'], inplace=True)

# %%
# Quick check on the structure
df_amazon_sr[['city_final', 'state', 'postal_code', 'latitude', 'longitude']].head()
# Out:
#        city_final        state postal_code  latitude  longitude
# 0     Barasat H.O  West Bengal      700124   22.4656    88.7803
# 1  Chikkabanavara    Karnataka      560090   13.2257    77.5750
# 2      Basai Road      Haryana      122001   28.4180    76.9839
# 3   Nallosapare E  Maharashtra      401209   19.3600    73.3279
# 4          Sahifa    Telangana      500024   17.4171    78.4772

# %%
# Drop old city column and replace with trusted GeoNames-based city
df_amazon_sr.drop(columns=['city'], inplace=True)
df_amazon_sr.rename(columns={'city_final': 'city'}, inplace=True)

# %%
df_amazon_sr.head()
# Out:
#               order_id       date                        status fulfilment  \
# 0  404-1445673-1345134 2022-04-01  Shipped - Delivered to Buyer   Merchant
# 1  406-7387241-2881923 2022-04-01                       Shipped     Amazon
# 2  402-9332104-0945115 2022-04-01                     Cancelled   Merchant
# 3  408-1008226-2450750 2022-04-01                       Shipped     Amazon
# 4  403-4108307-0229121 2022-04-01                       Shipped     Amazon
#
#   shipping_method    style              sku category size courier_status  ...  \
# 0        Standard  JNE3724     JNE3724-KR-L    Kurta    L        Shipped  ...
# 1       Expedited   SET187  SET187-KR-DH-XL      Set   XL        Shipped  ...
# 2        Standard  JNE3383   JNE3383-KR-A-M    Kurta    M            NaN  ...
# 3       Expedited  JNE3405     JNE3405-KR-L    Kurta    L        Shipped  ...
# 4       Expedited   SET044   SET044-KR-NP-L      Set    L        Shipped  ...
#
#    currency  amount        state postal_code    b2b  fulfilled_by  \
# 0       INR  495.00  West Bengal      700124  False     Easy Ship
# 1       INR  599.00    Karnataka      560090  False         Other
# 2       INR  416.19      Haryana      122001  False     Easy Ship
# 3       INR  449.00  Maharashtra      401209  False         Other
# 4       INR  542.00    Telangana      500024  False         Other
#
#                      promo_id latitude  longitude            city
# 0  Amazon PLCC Free-Financing  22.4656    88.7803     Barasat H.O
# 1                        None  13.2257    77.5750  Chikkabanavara
# 2                        None  28.4180    76.9839      Basai Road
# 3                        None  19.3600    73.3279   Nallosapare E
# 4                        None  17.4171    78.4772          Sahifa
#
# [5 rows x 21 columns]

# %%
df_amazon_sr['city'].nunique()
# Out:
# 9370

# %%
# Check for hidden null values
df_amazon_sr[df_amazon_sr['city'].isin(['', ' '])]
# Out:
# Empty DataFrame
# Columns: [order_id, date, status, fulfilment, shipping_method, style, sku, category, size, courier_status, qty, currency, amount, state, postal_code, b2b, fulfilled_by, promo_id, latitude, longitude, city]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Check for null values in 'city' and 'state' columns
df_amazon_sr[['city', 'state']].isnull().sum()
# Out:
# city     0
# state    1
# dtype: int64

# %%
# Investigate
df_amazon_sr[df_amazon_sr['state'].isnull()]
# Out:
#                  order_id       date     status fulfilment shipping_method  \
# 4564  405-0034289-0259545 2022-04-04  Cancelled     Amazon       Expedited
#
#       style          sku category size courier_status  ...  currency amount  \
# 4564  J0077  J0077-SKD-S      Set    S      Cancelled  ...       NaN    NaN
#
#       state postal_code    b2b  fulfilled_by promo_id latitude  longitude  \
# 4564   None      959121  False         Other     None      NaN        NaN
#
#       city
# 4564   Apo
#
# [1 rows x 21 columns]

# %%
# Drop row with 'Apo' city and missing state — cancelled and not monetized
df_amazon_sr = df_amazon_sr[~((df_amazon_sr['city'] == 'Apo') & (df_amazon_sr['state'].isnull()))]

# %%
sorted(df_amazon_sr['city'].dropna().unique().tolist())
# Out:
# ['(Gandhinagar) Sector 16',
#  '(Gandhinagar) Sector 23',
#  '(Gandhinagar) Sector 28',
#  '(Gandhinagar) Sector 29',
#  '(Gandhinagar) Sector 6',
#  '12z',
#  '14 S Majhiwala',
#  '15 Velampalayam',
#  '33 Bn. Pac Jhansi',
#  '63 Velampalayam',
#  '7 GD',
#  '71rb',
#  '7th Mile Kalimpong',
#  'A D Market',
#  'A F Station Yelahanka',
#  'A K Pora',
#  'A Kattupadi',
#  'A Kothapalle',
#  'A. H. Guard',
#  'A. Kiliyanur',
#  'A.A. College',
#  'A.B.V.Palem',
#  'A.D. Project',
#  'A.G.College',
#  'A.G.Office',
#  'A.Gs. Staff Quarters',
#  'A.I.E. R.C.puram',
#  'A.Katapali',
#  'A.P.Colony (Karim Nagar)',
#  'A.P.Dabolim',
#  'A.Pallipatti',
#  'AIIMS',
#  'AIMS Ponekkara',
#  'Aami',
#  'Aamtara',
#  'Aanole',
#  'Aareymilk Colony',
#  'Abadi Ramagundam',
#  'Abash',
#  'Abbarajupalem',
#  'Abdalpur',
#  'Abhanga',
#  'Abhayagiri',
#  'Abhiya Kalan',
#  'Abholi',
#  'Abhoynagar',
#  'Abhva',
#  'Abi Karlpora',
#  'Abinash Chaowdhury Lane',
#  'Abishegapakkam',
#  'Abubshahar',
#  'Abul Fazal Enclave-I',
#  'Abulga BK',
#  'Aburoad Gandhi Nagar',
#  'Acchad',
#  'Acharya Vihar',
#  'Achhipur',
#  'Achitnagar',
#  'Achladi',
#  'Achrol',
#  'Adaikalapattinam',
#  'Adajan Dn',
#  'Adampur',
#  'Adampur Janubi',
#  'Adani Port',
#  'Adarsh Nagar',
#  'Adarshnagar',
#  'Adasipada',
#  'Adavisoman Palli',
#  'Addampalli',
#  'Additional Ambernath',
#  'Addoor',
#  'Adenga',
#  'Adhanur',
#  'Adheigundi',
#  'Adigon',
#  'Adikantanagar',
#  'Adikashimpur',
#  'Adityanagar',
#  'Adityapur',
#  'Adityapur Industrial Area',
#  'Adivaram Pudupadi',
#  'Adkathbail',
#  'Adkur',
#  'Adloor',
#  'Adooki',
#  'Adsisar',
#  'Adtala',
#  'Adugodi',
#  'Adur( Kla) H.O',
#  'Advalpal',
#  'Adyal Tekadi',
#  'Adyanadka',
#  'Aerodrome',
#  'Aerodrome Area',
#  'Aerodromme',
#  'Afoi',
#  'Agaraohai',
#  'Agarpara',
#  'Agartala Bazar',
#  'Agartala ONGC',
#  'Agartala Secretariat',
#  'Agarthipalem',
#  'Agarwal Mandi',
#  'Agasaud',
#  'Agasteeswaram',
#  'Agasthiampalli',
#  'Agasthiyarpatti',
#  'Agasvan',
#  'Agathi',
#  'Agchia',
#  'Aggapur',
#  'Aghar KH',
#  'Agm Colony',
#  'Agon',
#  'Agra Chak',
#  'Agrahara Kannadiputhur',
#  'Agraharasamakulam',
#  'Agram',
#  'Agrico',
#  'Agricultur Research Station',
#  'Ahamedpur  Chauroli',
#  'Ahatguri',
#  'Ahemedanagar',
#  'Ahirauli Bujurg',
#  'Ahmad Dhandi',
#  'Ahmad Nagar Kalan',
#  'Ahmedabad',
#  'Ahmednagar H.O',
#  'Ahmedpur',
#  'Aie Bollaram',
#  'Aiginia',
#  'Ainavole',
#  'Ainghar',
#  'Aipur Ashta',
#  'Air Force',
#  'Air Port',
#  'Airforce Academy',
#  'Airoli',
#  'Airport (Pune)',
#  'Aishbagh',
#  'Aizawl H.O',
#  'Ajabpur',
#  'Ajagara Masharki',
#  'Ajairajpura',
#  'Ajana',
#  'Ajauli',
#  'Ajhai Kurd',
#  'Ajijnagar',
#  'Ajmer',
#  'Ajmer Road',
#  'Ajodhya',
#  'Ajrihara',
#  'Akalur',
#  'Akamkudy',
#  'Akasarawa',
#  'Akauri',
#  'Akhada Ward(Pandharkawada)',
#  'Akhtiyarpur',
#  'Akkampalli',
#  'Akkaparamba',
#  'Akkaraivattam',
#  'Akkarapadom',
#  'Akkinepally',
#  'Akna',
#  'Akohari',
#  'Akola City',
#  'Akouna',
#  'Akshi',
#  'Akulga Rani',
#  'Akurdi',
#  'Akwabad',
#  'Ala (Alappuzha)',
#  'Alaganur',
#  'Alagappanagar',
#  'Alagiamandapam',
#  'Alagianallur',
#  'Alaknur',
#  'Alakode',
#  'Alamanda R S',
#  'Alambadimines',
#  'Alambagh',
#  'Alamcode',
#  'Alamganj Bazar',
#  'Alampalayam',
#  'Alampur Mandra',
#  'Alanda',
#  'Alandi Chorachi',
#  'Alanganatham',
#  'Alankhan Palli',
#  'Alankinar',
#  'Alankode',
#  'Alapadu R.S.',
#  'Alappuzha Bazar',
#  'Alappuzha H.O',
#  'Alappuzha North',
#  'Alasahi',
#  'Alathiyur',
#  'Alathur',
#  'Alathur Mbr H.O',
#  'Alathur(Thrissur)',
#  'Alavil',
#  'Aletty',
#  'Alibag H.O',
#  'Alinagear Rajpur',
#  'Alipur Bihta',
#  'Alipur Jahangir',
#  'Alipur Madara',
#  'Alipurduar New Town',
#  'Aliyadu',
#  'Allahabad City',
#  'Allampalli.',
#  'Allapuram',
#  'Allehpur',
#  'Allinagaram',
#  'Allipingal',
#  'Allipur',
#  'Almat R.S.',
#  'Aloor',
#  'Althan',
#  'Alto Betim',
#  'Alubari',
#  'Alumkadavu',
#  'Alumoodu',
#  'Alungkima',
#  'Aluva-asokapuram',
#  'Alwai',
#  'Alwarkurichi',
#  'Alwarthirunagar',
#  'Amachavadi',
#  'Amadabakula',
#  'Amadagur',
#  'Amadalavalasa H.O',
#  'Amadi Beguide',
#  'Amalanagar',
#  'Amaliyara',
#  'Amar Colony',
#  'Amara',
#  'Amarambalam South',
#  'Amaravathi Road(Guntur)',
#  'Amarda',
#  'Amarpur',
#  'Amarpura Theri',
#  'Amatamravivalasa',
#  'Amausi Ad',
#  'Amayapra',
#  'Amba Bari',
#  'Ambada',
#  'Ambagaon',
#  'Ambala  City Kucthery',
#  'Ambalamedu',
#  'Ambalamukku',
#  'Ambalapadi',
#  'Ambalathara',
#  'Ambalathinnirappu',
#  'Ambale',
#  'Ambapani',
#  'Ambari Fatasil',
#  'Ambaribagan',
#  'Ambasamudram Angadi',
#  'Ambattur Indl Estate',
#  'Ambavane',
#  'Ambedare Bk',
#  'Ambedkarnagar',
#  'Ambegaon BK',
#  'Ambelohal',
#  'Ambeok',
#  'Ambernath South',
#  'Ambikapuram (Palakkad)',
#  'Ambilat',
#  'Ambipoika',
#  'Ambla',
#  'Ambligola',
#  'Ambota',
#  'Ambujanagar',
#  'Ambur Bazaar',
#  'Amda',
#  'Amdah',
#  'Amdalli',
#  'Ametahi',
#  'Amethi H.O',
#  'Amgaon BK',
#  'Amgaon Dighori',
#  'Amghatta',
#  'Amguri Haloating',
#  'Amichikary',
#  'Aminabad',
#  'Amity University',
#  'Amjadpur Pidhauli',
#  'Amla Depot',
#  'Amlai Paper Mills',
#  'Amlaiya Ashanand',
#  'Amlajora',
#  'Amlawad',
#  'Amleshwar',
#  'Amleta',
#  'Amlori Project',
#  'Ammachathiram',
#  'Ammadam',
#  'Ammajipeta',
#  'Ammaladinne',
#  'Ammatchiapuram',
#  'Ammundi',
#  'Ammunition Factory Khadki',
#  'Amodar',
#  'Amoli',
#  'Amousi',
#  'Ampad',
#  'Ampara Nirappel',
#  'Ampuram',
#  'Amrabati',
#  'Amragol',
#  'Amraiwadi',
#  'Amrapura',
#  'Amreli T.R',
#  'Amrita Bazar Partika',
#  'Amritanagar',
#  'Amritberia',
#  'Amrithapuri',
#  'Amritsar Kty',
#  'Amroli',
#  'Amruthpuram.',
#  'Amsinggaon E (S -85)',
#  'Amtal',
#  'Amtala (Mobile)',
#  'Amthala',
#  'Amudala',
#  'Amudarlanka',
#  'Amulla',
#  'Amwa Molvi',
#  'Anagar',
#  'Anaith',
#  'Anakaputhur',
#  'Anakkara (Palakkad)',
#  'Anand Nagar (Jabalpur)',
#  'Anand Nagar (Kanpur Nagar)',
#  'Anand Pur Sahib',
#  'Anandapuram',
#  'Anandapuri',
#  'Anandashram',
#  'Anandbagh',
#  'Anandnagar (Bangalore)',
#  'Anandnagar (Hyderabad)',
#  'Anandnagar (Pune)',
#  'Anandpur',
#  'Ananthavaram',
#  'Anantwadi',
#  'Anappara-kalady',
#  'Anastu',
#  'Anatana',
#  'Anathur',
#  'Anayara',
#  'Anchachavady',
#  'Anchampeedika',
#  'Anchiri',
#  'Andada',
#  'Andagalur',
#  'Andathode',
#  'Andharia',
#  'Andharra',
#  'Andheri H.O',
#  'Andheri Railway Station',
#  'Andhra',
#  'Andipalayam',
#  'Andirapuram',
#  'Andole',
#  'Andugula Kothapalem',
#  'Angale',
#  'Angarankuppam',
#  'Angeswarpada',
#  'Angnakol',
#  'Angul H.O',
#  'Angus',
#  'Anikad East',
#  'Anikad Mallappally GDS',
#  'Animoor',
#  'Anirudhpur',
#  'Anisabad',
#  'Anjale',
#  'Anjanapura',
#  'Anjilithanam',
#  'Anjoottimangalam',
#  'Anjur Mundur',
#  'Ankalammapeta',
#  'Ankalge',
#  'Ankali',
#  'Ankasapur',
#  'Ankireddypalli',
#  'Ankoderu',
#  'Ankula',
#  'Anlo',
#  'Anna Nagar (Chennai)',
#  'Anna Nagar (Madurai)',
#  'Anna Nagar East',
#  'Anna Nagar Western Extn',
#  'Anna Road H.O',
#  'Annai Anjugam Nagar',
#  'Annanad',
#  'Annanagar',
#  'Annareddypalem',
#  'Annaruguda',
#  'Annasseri',
#  'Anoor',
#  'Anpara Tps',
#  'Ansari Nagar',
#  'Ansur',
#  'Antala',
#  'Antarvedi Devastanam',
#  'Antharaghatta',
#  'Anthikad',
#  'Anthinad',
#  'Anthrakudda',
#  'Anumpalli',
#  'Anupuram',
#  'Anushakti Nagar',
#  'Anuvijay Township',
#  'Anwari',
#  'Aolaguri',
#  'Apna Bazar',
#  'Apoti',
#  'Appakudal',
#  'Appanaickenpatti',
#  'Apparaopalle',
#  'Appareddipally',
#  'Apsarkonda',
#  'Aquem',
#  'Arabi',
#  'Aradali',
#  'Araimile',
#  'Arakinar',
#  'Arakkonam H.O',
#  'Arakunnam',
#  'Arale',
#  'Aralikatte',
#  'Aralvaymoli',
#  'Aramada',
#  'Arambagh Court',
#  'Arameri',
#  'Aranattukara',
#  'Aranga Purusottampur',
#  'Arara',
#  'Arasur',
#  'Arattupuzha',
#  'Aravakothur',
#  'Arcot West',
#  'Are',
#  'Areekara',
#  'Areeparampu',
#  'Arekandige',
#  'Arethi',
#  'Arga',
#  'Ariadaha',
#  'Arif Ke',
#  'Arignar Anna Nagar',
#  'Arikulam',
#  'Aril',
#  'Arilova',
#  'Arinjerummal',
#  'Arisipalayam',
#  'Arit',
#  'Ariyallur',
#  'Arjheri',
#  'Arkaura',
#  'Arkdhibariya',
#  'Arkutipur',
#  'Arla',
#  'Arliganur',
#  'Armament',
#  'Armapore',
#  'Armed Veng',
#  'Armoor H.O',
#  'Army Head Quarter',
#  'Arn Behal',
#  'Arnakatte',
#  'Arnala',
#  'Arni CPT',
#  'Arnia Joshi',
#  'Arniya',
#  'Arogyamandir',
#  'Aroor',
#  'Arpookara East',
#  'Arpora',
#  'Arrah H.O',
#  'Arsikere H.O',
#  'Arth Jhikli',
#  'Arthingal',
#  'Arugolanu',
#  'Arugonda',
#  'Arumanoor',
#  'Arumanur',
#  'Arunachal University',
#  'Arunagirichatram',
#  'Arundalpet',
#  'Aruppukottai East',
#  'Arvi',
#  'Arwaliya',
#  'Arya Nagar (Haridwar)',
#  'Aryapuram',
#  'Asada',
#  'Asalwas Marheta',
#  'Asanchua',
#  'Asarfpur',
#  'Asarwa Ext South',
#  'Asdhna',
#  'Ashanagar',
#  'Ashapur',
#  'Ashiananagar',
#  'Ashidha',
#  'Ashok Ashram',
#  'Ashok Nagar',
#  'Ashok Nagar (Gorakhpur)',
#  'Ashok Nagar (Nashik)',
#  'Ashoka Park Extn.',
#  'Ashoknagar (Chennai)',
#  'Ashoknagar (Kurnool)',
#  'Ashoknagar(MR)',
#  'Ashrafpur Majhagawan',
#  'Ashram Road -Nadiad',
#  'Ashwathapura',
#  'Ashwini Nagar',
#  'Asia Plato',
#  'Aska H.O',
#  'Asma',
#  'Asoknagar R/s',
#  'Asoor',
#  'Asramom',
#  'Asrawan',
#  'Assam Agriculture University',
#  'Assam Medical College',
#  'Assam Sachivalaya',
#  'Assam Tribune',
#  'Astichak',
#  'Astoli',
#  'Aswathapur',
#  'Asylum Lane',
#  'Ataula',
#  'Atchampet',
#  'Atchampeta',
#  'Atchannapalem',
#  'Atchutapuram',
#  'Atchutapuratriam',
#  'Athagarh College',
#  'Athani Thrissur',
#  'Athicode',
#  'Athikaripatti',
#  'Athikattukulangara',
#  'Athinad North',
#  'Athipatu',
#  'Athipuliyur',
#  'Athirampuzha',
#  'Athirumkal',
#  'Athokpam',
#  'Athota',
#  'Athu Pollachi',
#  'Athwalines',
#  'Atigre',
#  'Atirajpur',
#  'Atkur',
#  'Atkuru',
#  'Atone',
#  'Atoos',
#  'Ator Nagla',
#  'Atpadi',
#  'Atta',
#  'Attakulangara',
#  'Attapur',
#  'Attingal H.O',
#  'Attukkal',
#  'Attur',
#  'Audahi Kalan',
#  'Aulina',
#  'Aun',
#  'Aundh (Pune)',
#  'Aundipatti',
#  'Aunta',
#  'Aurangabad (Varanasi)',
#  'Aurangabad Kutchehry',
#  'Auria Kalan',
#  'Aurvacode',
#  'Autonagar',
#  'Avadayarpattu',
#  'Avadi Camp H.O',
#  'Avadi IAF',
#  'Avakhal',
#  'Avanigadda H.O',
#  'Avanivapuram',
#  'Avas Vikas Colony',
#  'Avhane',
#  'Avichipatti',
#  'Avinab Bidanasi',
#  'Awadh Nagar',
#  'Awalapur',
#  'Awan',
#  'Awan Bikeshah',
#  'Awang Leikinthabi',
#  'Awarkhod',
#  'Awayen',
#  'Ayali Kalan',
#  'Ayalur',
#  'Ayamkudy',
#  'Ayanathampatti',
#  'Ayilam',
#  'Ayiranikudy',
#  'Aynavaram',
#  'Ayodhaya Nagar',
#  'Ayroor South',
#  'Ayyamperumalpatti',
#  'Ayyampet',
#  'Ayyankalipalayam',
#  'Ayyanthole',
#  'Ayyavaripally',
#  'Azad Society',
#  'Azadnagar',
#  'Azamgarh H.O',
#  'Azamnagar Chopra',
#  'Azampur Bisaria',
#  'Azhakappapuram',
#  'Azheekkalthura',
#  'Azhikkal',
#  'Azhikode Jetty',
#  'Azhikode South',
#  'Azhiyadathuchira',
#  'Azhurmarket',
#  'B I Estate',
#  'B K Tarlagatta',
#  'B R A University',
#  'B.Beeranahalli',
#  'B.D.Sopan',
#  'B.Fatkara',
#  'B.Gowdagere',
#  'B.H.Colony',
#  'B.Kesho',
#  'B.Kolakudi',
#  'B.Kondepadu',
#  'B.Kutung',
#  'B.M.G. Hospital Ramnagar',
#  'B.Machavaram',
#  'B.N. Bhavan',
#  'B.P Oilmill',
#  'B.Polytechnic',
#  'B.Salwadgi',
#  'B.Simaria',
#  'B.T.P.P',
#  'B.Tandrapadu',
#  'BARC',
#  'BCCl Township',
#  'BESA Road',
#  'BHEL (Jhansi)',
#  'BOWAKALAM',
#  'BPC Gandhinagar',
#  'BSF Campus',
#  'Baad(KWR)',
#  'Baalai Bujurg',
#  'Babhana',
#  'Babhanbay',
#  'Babhani Kanoongo',
#  'Babultali',
#  'Babupeth',
#  'Babusarai',
#  'Bachamari',
#  'Bachhawal',
#  'Bachhunchh',
#  'Bachpora',
#  'Bacon Factory',
#  'Badabaragam',
#  'Badagarh Brit Colony',
#  'Badagayedapadavu',
#  'Badagotha',
#  'Badaharia',
#  'Badaitari',
#  'Badajamposi',
#  'Badakul',
#  'Badakula',
#  'Badalapur Khurd',
#  'Badamtam',
#  'Badamulabasanta',
#  'Badangpet',
#  'Badapari',
#  'Badapokharan',
#  'Badaposi',
#  'Badaputi',
#  'Badarpur (Karimganj)',
#  'Badartala',
#  'Badatribida',
#  'Badaundwa',
#  'Badekakler',
#  'Badekanera',
#  'Badem',
#  'Badenawapara',
#  'Badesera',
#  'Badgaon',
#  'Badgawan',
#  'Badhar',
#  'Badkhar',
#  'Badkheda',
#  'Badkuleibira',
#  'Badlapur',
#  'Badli (North West Delhi)',
#  'Badmouda',
#  'Badoh',
#  'Badon',
#  'Badrada',
#  'Badrathakur',
#  'Baduguvanilanka',
#  'Badupuram',
#  'Badusar',
#  'Badwa',
#  'Badya Brahamana',
#  'Bag Mungalia',
#  'Bagadganj',
#  'Bagahod',
#  'Bagalkot DC Complex',
#  'Bagalkot H.O',
#  'Bagalsahi',
#  'Bagalwada',
#  'Bagankheda',
#  'Bagari',
#  'Bagcholi Khar',
#  'Bagdhar',
#  'Bagdigi',
#  'Bagh Mehtab',
#  'Baghajatin',
#  'Baghdoba',
#  'Baghibazar',
#  'Baghpat Sugar Mill',
#  'Baghshumout',
#  'Baghsiuni',
#  'Bagnadi',
#  'Bagouta',
#  'Bagras',
#  'Baguiati Super Market',
#  'Bagwara',
#  'Bahadurpurghar',
#  'Bahamanian',
#  'Bahang',
#  'Baharia Bazar',
#  'Bahdura',
#  'Baherabandh',
#  'Bahgarh',
#  'Bahirchak',
#  'Bahjoi',
#  'Bahowal',
#  'Bahror H.O',
#  'Baichanahally',
#  'Baidyabati',
#  'Baijagwada',
#  'Baijani',
#  'Baikampady',
#  'Baikhedi',
#  'Baimanagoi',
#  'Bairasar',
#  'Bairatiguri',
#  'Baitapalle',
#  'Baithalangsho',
#  'Bajaj Nagar Midc Waluj',
#  'Bajekumarpur',
#  'Bajepratappur NDDF',
#  'Bajhera  Bujurg',
#  'Bajidpur Tappa Haveli',
#  'Bajirao Road',
#  'Bajjoana',
#  'Bajwa',
#  'Bakabedi',
#  'Bakery Road',
#  'Bakewar Sarai',
#  'Bakhalag',
#  'Bakkananagaripalle',
#  'Bakoli',
#  'Baksara',
#  'Baksh Pur',
#  'Bakulbahi',
#  'Bal Sarai',
#  'Bala',
#  'Balacheruvu',
#  'Balada',
#  'Baladia',
#  'Baladuan',
#  'Balaiya Jagdishpur',
#  'Balamau Village',
#  'Balambi(Chembu)',
#  'Balampur',
#  'Balanda',
#  'Balasaur',
#  'Balat',
#  'Balco Nagar Korba',
#  'Balele',
#  'Balethottam',
#  'Balh',
#  'Balhkwar',
#  'Baliamehra',
#  'Balibaruan',
#  'Balidih',
#  'Balihari',
#  'Balijan North Te',
#  'Balijan Te',
#  'Balijuri',
#  'Balipasi',
#  'Balipukhuri Tiniali',
#  'Balireddypalem',
#  'Balitikuri',
#  'Balkasa',
#  'Ballahar Chhak',
#  'Balli Ijassa Kheda',
#  'Ballygunge Sc College',
#  'Balol',
#  'Balraj Nagar',
#  'Balsmand',
#  'Baltana',
#  'Balthila',
#  'Balua',
#  'Balubhang',
#  'Balugloa',
#  'Balukaram',
#  'Balusupadu',
#  'Bam Kolakhowa',
#  'Bamangachi',
#  'Bambolim Camp',
#  'Bambolim Complex',
#  'Bamdera',
#  'Bamhori Madawra',
#  'Bamori Bika',
#  'Bamrauli',
#  'Bamunimaidan',
#  'Bamunpukur',
#  'Ban',
#  'Banaganapalle South',
#  'Banailipatti',
#  'Banakal',
#  'Banakanadoni',
#  'Banashankari',
#  'Banashankari III Stage',
#  'Banasthali Vidya Peeth',
#  'Banavadi',
#  'Banbaligara',
#  'Bandakothapally',
#  'Bandalingampalli',
#  'Bandarguri',
#  'Bandel Junction',
#  'Banderjud',
#  'Bandhawa Rajwar',
#  'Bandihatti',
#  'Bandikodigehalli',
#  'Bandlapalli',
#  'Bandomunda',
#  'Bandra West',
#  'Bandraotha',
#  'Bandu',
#  'Bangalanagar',
#  'Bangalore',
#  'Bangalore Corporation Building',
#  'Bangalore Dist Offices Bldg',
#  'Bangalore Sub Foreign Post',
#  'Bangidhar',
#  'Bangodaya',
#  'Bangra',
#  'Baniapal',
#  'Baniasahi',
#  'Banipur',
#  'Banjara Hills',
#  'Banjariya',
#  'Banjipet',
#  'Bank Street (Nalgonda)',
#  'Bankati',
#  'Bankatwa Dehat',
#  'Banke',
#  'Banker Street',
#  'Bankhedi Reva',
#  'Bankhedi(BMR)',
#  'Banki Mongra',
#  'Bankipore Macchariyawan',
#  'Bankra',
#  'Bankuiya',
#  'Bankumari E/SB',
#  'Banmalipurpatna',
#  'Bannahalli Hundi',
#  'Bansankra',
#  'Bansdei',
#  'Bansi',
#  'Bansnerkala',
#  'Bansra',
#  'Banswara',
#  'Bantalab',
#  'Banthra',
#  'Banthri',
#  'Banti Khera',
#  'Bapagrama',
#  'Baparde',
#  'Bapere',
#  'Bapiraju Kothapalli',
#  'Bapuji Vidyanagara',
#  'Bara',
#  'Bara (Ghazipur)',
#  'Bara Atagi',
#  'Bara Gokul Nagar',
#  'Bara Jodh Singh',
#  'Barabanki Bazar',
#  'Barachiru',
#  'Baragaonpimpri',
#  'Baragarrah',
#  'Baragochha',
#  'Barakar',
#  'Barakashipur',
#  'Baralimari',
#  'Baramadpur Lohra',
#  'Baramunda Colony',
#  'Baranberia',
#  'Barandari Bagaria',
#  'Baranihary',
#  'Baranpura',
#  'Barasat H.O',
#  'Barasolapur',
#  'Baratooti',
#  'Barchi',
#  'Barda',
#  'Bardhaman',
#  'Bardoli H.O',
#  'Bardwari',
#  'Bareilly',
#  'Bargadwa Harriya',
#  'Bargaon',
#  'Bargarh Bazar',
#  'Bargarh-bargaon',
#  'Bargi',
#  'Barh Court',
#  'Barhaun',
#  'Barhera',
#  'Barhouuia',
#  'Bari',
#  'Bari Brahmna',
#  'Bariath',
#  'Baridih Colony',
#  'Barigoan',
#  'Baripada Court',
#  'Barisakhi',
#  'Barisha',
#  'Barkakana',
#  'Barkakana NTS',
#  'Barkatpura',
#  'Barkheda  Pitramal',
#  'Barkhedakalan',
#  'Barkhedi',
#  'Barkholu',
#  'Barlongpher',
#  'Barlowganj',
#  'Barnala Kty',
#  'Baroda Chhedi',
#  'Baroli',
#  'Baroona',
#  'Barouli Basdev Pur',
#  'Barpalikala',
#  'Barra',
#  'Barra Vishwa Bank Sector-A',
#  'Barsian',
#  'Baruipur H.O',
#  'Barul',
#  'Barvav',
#  'Barve Nagar',
#  'Basai Road',
#  'Basani',
#  'Basanthnagar',
#  'Basanti Colony',
#  'Basantinagar',
#  'Basawa',
#  'Basbitti',
#  'Bashbera',
#  'Basi Kiratapur',
#  'Basinepalli',
#  'Basirhat Bazar',
#  'Baskepi',
#  'Baslambi',
#  'Basmathnagar Town',
#  'Bassi',
#  'Bassi (Chittorgarh)',
#  'Bassi Kehloor',
#  'Bassian Brahman',
#  'Bastacola',
#  'Basti',
#  'Basti Bagra',
#  'Basti Guzan',
#  'Basti H.O',
#  'Basti Sugar Factory',
#  'Basuari',
#  'Basuki Bihari',
#  'Bataganj',
#  'Batawada',
#  'Batertal',
#  'Batesra',
#  'Batgharia',
#  'Bathalapalli',
#  'Bathinda Cantt',
#  'Bathindi',
#  'Bati',
#  'Batiatala',
#  'Batkangale',
#  'Batpora',
#  'Batrakagallu',
#  'Batranau',
#  'Batwara',
#  'Baunsapokhari',
#  'Bawada',
#  ...]

# %%
# Check column order
df_amazon_sr.columns.tolist()
# Out:
# ['order_id',
#  'date',
#  'status',
#  'fulfilment',
#  'shipping_method',
#  'style',
#  'sku',
#  'category',
#  'size',
#  'courier_status',
#  'qty',
#  'currency',
#  'amount',
#  'state',
#  'postal_code',
#  'b2b',
#  'fulfilled_by',
#  'promo_id',
#  'latitude',
#  'longitude',
#  'city']

# %%
# Reorder column names
df_amazon_sr = df_amazon_sr[
    [
        'date', 'order_id', 'shipping_method', 'status', 'fulfilment', 
        'courier_status', 'category', 'style', 'sku', 'size', 'qty',
        'amount', 'currency', 'city','state', 'postal_code',
        'latitude', 'longitude', 'promo_id', 'fulfilled_by', 'b2b'
    ]
]

# %%
df_amazon_sr.head()
# Out:
#         date             order_id shipping_method  \
# 0 2022-04-01  404-1445673-1345134        Standard
# 1 2022-04-01  406-7387241-2881923       Expedited
# 2 2022-04-01  402-9332104-0945115        Standard
# 3 2022-04-01  408-1008226-2450750       Expedited
# 4 2022-04-01  403-4108307-0229121       Expedited
#
#                          status fulfilment courier_status category    style  \
# 0  Shipped - Delivered to Buyer   Merchant        Shipped    Kurta  JNE3724
# 1                       Shipped     Amazon        Shipped      Set   SET187
# 2                     Cancelled   Merchant            NaN    Kurta  JNE3383
# 3                       Shipped     Amazon        Shipped    Kurta  JNE3405
# 4                       Shipped     Amazon        Shipped      Set   SET044
#
#                sku size  ...  amount  currency            city        state  \
# 0     JNE3724-KR-L    L  ...  495.00       INR     Barasat H.O  West Bengal
# 1  SET187-KR-DH-XL   XL  ...  599.00       INR  Chikkabanavara    Karnataka
# 2   JNE3383-KR-A-M    M  ...  416.19       INR      Basai Road      Haryana
# 3     JNE3405-KR-L    L  ...  449.00       INR   Nallosapare E  Maharashtra
# 4   SET044-KR-NP-L    L  ...  542.00       INR          Sahifa    Telangana
#
#   postal_code latitude  longitude                    promo_id fulfilled_by  \
# 0      700124  22.4656    88.7803  Amazon PLCC Free-Financing    Easy Ship
# 1      560090  13.2257    77.5750                        None        Other
# 2      122001  28.4180    76.9839                        None    Easy Ship
# 3      401209  19.3600    73.3279                        None        Other
# 4      500024  17.4171    78.4772                        None        Other
#
#      b2b
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
# [5 rows x 21 columns]

# %%
# Check for duplicates
print(df_amazon_sr.duplicated().sum())
# Out:
# 6

# %%
# Inspect the 6 pairs of duplicates
dupes = df_amazon_sr[df_amazon_sr.duplicated(keep=False)]
display(dupes)
# Out:
#              date             order_id shipping_method     status fulfilment  \
# 7090   2022-04-06  408-0373839-4433120       Expedited  Cancelled     Amazon
# 7091   2022-04-06  408-0373839-4433120       Expedited  Cancelled     Amazon
# 18868  2022-04-13  406-0372545-6086735       Expedited  Cancelled     Amazon
# 18869  2022-04-13  406-0372545-6086735       Expedited  Cancelled     Amazon
# 53139  2022-05-04  171-3249942-2207542       Expedited    Shipped     Amazon
# 53140  2022-05-04  171-3249942-2207542       Expedited    Shipped     Amazon
# 55135  2022-05-04  405-8669298-3850736       Expedited    Shipped     Amazon
# 55136  2022-05-04  405-8669298-3850736       Expedited    Shipped     Amazon
# 60856  2022-05-08  171-9628368-5329958       Expedited  Cancelled     Amazon
# 60899  2022-05-08  171-9628368-5329958       Expedited  Cancelled     Amazon
# 120186 2022-06-23  407-4853873-4978725       Expedited    Shipped     Amazon
# 120196 2022-06-23  407-4853873-4978725       Expedited    Shipped     Amazon
#
#        courier_status category    style              sku size  ...  amount  \
# 7090        Cancelled    Kurta  JNE3501     JNE3501-KR-M    M  ...     NaN
# 7091        Cancelled    Kurta  JNE3501     JNE3501-KR-M    M  ...     NaN
# 18868       Cancelled      Set   SET197   SET197-KR-NP-L    L  ...     NaN
# 18869       Cancelled      Set   SET197   SET197-KR-NP-L    L  ...     NaN
# 53139         Shipped      Set   SET323  SET323-KR-NP-XL   XL  ...   939.0
# 53140         Shipped      Set   SET323  SET323-KR-NP-XL   XL  ...   939.0
# 55135         Shipped    Kurta  MEN5025  MEN5025-KR-XXXL  3XL  ...   533.0
# 55136         Shipped    Kurta  MEN5025  MEN5025-KR-XXXL  3XL  ...   533.0
# 60856       Cancelled    Kurta    J0329       J0329-KR-L    L  ...     NaN
# 60899       Cancelled    Kurta    J0329       J0329-KR-L    L  ...     NaN
# 120186        Shipped      Set    J0230      J0230-SKD-M    M  ...  1163.0
# 120196        Shipped      Set    J0230      J0230-SKD-M    M  ...  1163.0
#
#         currency                 city          state postal_code latitude  \
# 7090         NaN  Nagarbhavi II Stage      Karnataka      560072  13.2257
# 7091         NaN  Nagarbhavi II Stage      Karnataka      560072  13.2257
# 18868        NaN             Lohapool    West Bengal      734008  26.9135
# 18869        NaN             Lohapool    West Bengal      734008  26.9135
# 53139        INR              Marunji    Maharashtra      411057  18.6032
# 53140        INR              Marunji    Maharashtra      411057  18.6032
# 55135        INR    Hasanpur Bhowapur  Uttar Pradesh      201010  28.7643
# 55136        INR    Hasanpur Bhowapur  Uttar Pradesh      201010  28.7643
# 60856        NaN               Kaloor         Kerala      682017   9.9670
# 60899        NaN               Kaloor         Kerala      682017   9.9670
# 120186       INR     Dayalpur Sodhian         Punjab      140603  30.2803
# 120196       INR     Dayalpur Sodhian         Punjab      140603  30.2803
#
#         longitude  promo_id fulfilled_by    b2b
# 7090      77.5750      None        Other  False
# 7091      77.5750      None        Other  False
# 18868     88.3947      None        Other  False
# 18869     88.3947      None        Other  False
# 53139     73.7626      None        Other  False
# 53140     73.7626      None        Other  False
# 55135     77.4856      None        Other  False
# 55136     77.4856      None        Other  False
# 60856     76.3159      None        Other  False
# 60899     76.3159      None        Other  False
# 120186    76.3516      None        Other  False
# 120196    76.3516      None        Other  False
#
# [12 rows x 21 columns]

# %%
# Check that they are identical
dupes.iloc[0].equals(dupes.iloc[1])
# Out:
# True

# %%
# Drop them and check
df_amazon_sr.drop_duplicates(inplace=True)
print(df_amazon_sr.duplicated().sum())
# Out:
# 0

# %%
# Check missing values
missing = df_amazon_sr.isnull().sum()
missing = missing[missing > 0].sort_values(ascending=False)
display(missing)
# Out:
# amount            7665
# currency          7665
# courier_status    6869
# latitude          1172
# longitude         1172
# dtype: int64

# %%
# Check missing lat/lon first
df_amazon_sr[df_amazon_sr['latitude'].isnull()][['postal_code', 'state', 'city']].head(10)
# Out:
#      postal_code           state         city
# 62        600080      Tamil Nadu      Chennai
# 93        400705     Maharashtra  Navi Mumbai
# 624       410209     Maharashtra  Navi Mumbai
# 702       629603      Tamil Nadu    Nagercoil
# 707       380025         Gujarat    Ahmedabad
# 730       302023       Rajasthan       Jaipur
# 746       462021  Madhya Pradesh       Bhopal
# 849       500073  Andhra Pradesh    Hyderabad
# 917       688547          Kerala        Aroor
# 1110      144013          Punjab    Jalandhar

# %%
missing_postals = df_amazon_sr[df_amazon_sr['latitude'].isnull()]['postal_code'].nunique()
print(f'Postal codes with missing lat/lon: {missing_postals}')
# Out:
# Postal codes with missing lat/lon: 222

# %%
# Note: Although 1,172 rows are missing lat/lon, they come from only 222 unique postal codes.
# Tableau aggregates by postal code, so these rows collapse into fewer map points.
# In Tableau, only 1 unmapped location appears — acceptable for now.
# Leaving these rows in the dataset in case we want to patch coordinates later.

# %%
# Missing amount/currency
# Check to see if the 7665 rows with missing amount values were cancelled and that's why they are missing
df_amazon_sr[df_amazon_sr['amount'].isnull()]['status'].value_counts()
# Out:
# status
# Cancelled                       7559
# Shipped                           93
# Shipped - Delivered to Buyer       8
# Shipped - Returned to Seller       3
# Pending                            2
# Name: count, dtype: int64

# %%
# Most (7559) but not all (7665) were cancelled. 106 non-cancelled orders are missing currency/amount

# %%
# Add a column to flag rows that have a valid (non-null) 'amount' value to track which orders contain real payment data
df_amazon_sr['has_amount'] = df_amazon_sr['amount'].notna()

# %%
# Create a separate dataframe for completed, paid orders
df_amazon_sr_paid = df_amazon_sr[
    (df_amazon_sr['amount'].notna()) &
    (df_amazon_sr['status'] != 'Cancelled')
].copy() # prevent unwanted links to the original dataframe

# %%
df_amazon_sr.head()
# Out:
#         date             order_id shipping_method  \
# 0 2022-04-01  404-1445673-1345134        Standard
# 1 2022-04-01  406-7387241-2881923       Expedited
# 2 2022-04-01  402-9332104-0945115        Standard
# 3 2022-04-01  408-1008226-2450750       Expedited
# 4 2022-04-01  403-4108307-0229121       Expedited
#
#                          status fulfilment courier_status category    style  \
# 0  Shipped - Delivered to Buyer   Merchant        Shipped    Kurta  JNE3724
# 1                       Shipped     Amazon        Shipped      Set   SET187
# 2                     Cancelled   Merchant            NaN    Kurta  JNE3383
# 3                       Shipped     Amazon        Shipped    Kurta  JNE3405
# 4                       Shipped     Amazon        Shipped      Set   SET044
#
#                sku size  ...  currency            city        state  \
# 0     JNE3724-KR-L    L  ...       INR     Barasat H.O  West Bengal
# 1  SET187-KR-DH-XL   XL  ...       INR  Chikkabanavara    Karnataka
# 2   JNE3383-KR-A-M    M  ...       INR      Basai Road      Haryana
# 3     JNE3405-KR-L    L  ...       INR   Nallosapare E  Maharashtra
# 4   SET044-KR-NP-L    L  ...       INR          Sahifa    Telangana
#
#   postal_code latitude longitude                    promo_id  fulfilled_by  \
# 0      700124  22.4656   88.7803  Amazon PLCC Free-Financing     Easy Ship
# 1      560090  13.2257   77.5750                        None         Other
# 2      122001  28.4180   76.9839                        None     Easy Ship
# 3      401209  19.3600   73.3279                        None         Other
# 4      500024  17.4171   78.4772                        None         Other
#
#      b2b has_amount
# 0  False       True
# 1  False       True
# 2  False       True
# 3  False       True
# 4  False       True
#
# [5 rows x 22 columns]

# %%
# Fill missing courier_status values
# Check how many missing values exist in 'courier_status'
df_amazon_sr['courier_status'].isnull().sum()
# Out:
# np.int64(6869)

# %%
# Check to see if NaN values in courier_status are == status 'Cancelled'
df_amazon_sr[df_amazon_sr['courier_status'].isnull()]['status'].value_counts()
# Out:
# status
# Cancelled                       6858
# Shipped - Delivered to Buyer       8
# Shipped - Returned to Seller       3
# Name: count, dtype: int64

# %%
# Of the 6869 missing courier_status values, 6858 are cancelled. Remaining 11 are in-between or post-ship states

# %%
# Only fill NaNs in courier_status where status is "Cancelled", leave the 11 NaNs
df_amazon_sr.loc[
    (df_amazon_sr['courier_status'].isnull()) & (df_amazon_sr['status'] == 'Cancelled'),
    'courier_status'
] = 'Unshipped'

df_amazon_sr_paid.loc[
    (df_amazon_sr_paid['courier_status'].isnull()) & (df_amazon_sr_paid['status'] == 'Cancelled'),
    'courier_status'
] = 'Unshipped'

# %%
# Check for suspicious rows: qty == 0 but status is not cancelled
df_amazon_sr[(df_amazon_sr['qty'] == 0) & (df_amazon_sr['status'] != 'Cancelled')].head()
# Out:
#            date             order_id shipping_method   status fulfilment  \
# 116  2022-04-01  407-9562445-9572337       Expedited  Shipped     Amazon
# 506  2022-04-02  407-7550181-9573127       Expedited  Shipped     Amazon
# 543  2022-04-02  405-7650095-6300317       Expedited  Shipped     Amazon
# 1414 2022-04-02  403-7603946-1101919       Expedited  Shipped     Amazon
# 1468 2022-04-02  406-7490066-8351568       Expedited  Shipped     Amazon
#
#      courier_status category    style              sku size  ...  currency  \
# 116       Cancelled    Kurta  JNE3465     JNE3465-KR-L    L  ...       NaN
# 506       Cancelled      Set   SET331  SET331-KR-NP-XS   XS  ...       NaN
# 543       Cancelled    Kurta  JNE3405     JNE3405-KR-S    S  ...       NaN
# 1414      Cancelled      Set    J0251     J0251-SKD-XS   XS  ...       NaN
# 1468      Cancelled      Set   SET349   SET349-KR-NP-L    L  ...       NaN
#
#                         city        state postal_code latitude longitude  \
# 116       Karnal Sadar Bazar      Haryana      132001  29.6875   76.8847
# 506              Rangailunda       Odisha      760007  19.3355   84.8685
# 543             J.J.Hospital  Maharashtra      400008  18.9474   72.8138
# 1414          Hastal Village        Delhi      110059  28.6553   77.0657
# 1468  Sector 44 (Chandigarh)   Chandigarh      160047  30.7080   76.7621
#
#       promo_id  fulfilled_by    b2b has_amount
# 116       None         Other  False      False
# 506       None         Other  False      False
# 543       None         Other  False      False
# 1414      None         Other  False      False
# 1468      None         Other  False      False
#
# [5 rows x 22 columns]

# %%
# Drop rows with qty == 0 that aren't cancelled (likely invalid)
df_amazon_sr = df_amazon_sr[~((df_amazon_sr['qty'] == 0) & (df_amazon_sr['status'] != 'Cancelled'))]

# %%
# Clean up 'status' colums values

# %%
df_amazon_sr['status'].unique()
# Out:
# array(['Shipped - Delivered to Buyer', 'Shipped', 'Cancelled',
#        'Shipped - Returned to Seller', 'Shipped - Rejected by Buyer',
#        'Pending', 'Shipped - Picked Up', 'Shipped - Returning to Seller',
#        'Shipped - Out for Delivery', 'Shipped - Lost in Transit',
#        'Shipped - Damaged', 'Pending - Waiting for Pick Up'], dtype=object)

# %%
# Check all unique 'status' values and how many times each appears
df_amazon_sr['status'].value_counts(dropna=False)
# Out:
# status
# Shipped                          77577
# Shipped - Delivered to Buyer     28754
# Cancelled                        18320
# Shipped - Returned to Seller      1947
# Shipped - Picked Up                973
# Pending                            656
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: count, dtype: int64

# %%
# Drop 6 rows with problematic shipping statuses — damaged, or lost in transit
problematic_statuses = [
    'Shipped - Damaged',
    'Shipped - Lost in Transit'
]

df_amazon_sr = df_amazon_sr[
    ~df_amazon_sr['status'].isin(problematic_statuses)
]
df_amazon_sr_paid = df_amazon_sr_paid[
    ~df_amazon_sr_paid['status'].isin(problematic_statuses)
]

# %%
# Create a simplified 'status_clean' column for grouping and analysis

def clean_order_status(status, amount):
    if status.startswith('Cancelled'):
        return 'Cancelled'
    if status.startswith('Pending'):
        return 'Pending'
    if status in [
        'Shipped',
        'Shipped - Delivered to Buyer',
        'Shipped - Picked Up',
        'Shipped - Out for Delivery'
    ]:
        if amount == 0:
            return 'Shipped - Replacement'
        return 'Shipped'
    if status in [
        'Shipped - Returned to Seller',
        'Shipped - Rejected by Buyer',
        'Shipped - Returning to Seller'
    ]:
        return 'Returned'
    return 'Unknown'

# %%
df_amazon_sr['status_clean'] = df_amazon_sr.apply(
    lambda row: clean_order_status(row['status'], row['amount']),
    axis=1
)

df_amazon_sr_paid['status_clean'] = df_amazon_sr_paid.apply(
    lambda row: clean_order_status(row['status'], row['amount']),
    axis=1
)

# %%
# Cross-tab to check how status_clean aligns with courier_status
df_amazon_sr.groupby(['status_clean', 'courier_status']).size().unstack(fill_value=0)
# Out:
# courier_status         Cancelled  Shipped  Unshipped
# status_clean
# Cancelled                   5834        0      12486
# Pending                        0       10        927
# Returned                       0     2103          0
# Shipped                        0   105077          0
# Shipped - Replacement          0     2262          0

# %%
# Tag weird rows with new column status_mismatch
df_amazon_sr['status_mismatch'] = (
    ((df_amazon_sr['status_clean'] == 'Pending') & (df_amazon_sr['courier_status'] == 'Shipped'))
)
df_amazon_sr.head()
# Out:
#         date             order_id shipping_method  \
# 0 2022-04-01  404-1445673-1345134        Standard
# 1 2022-04-01  406-7387241-2881923       Expedited
# 2 2022-04-01  402-9332104-0945115        Standard
# 3 2022-04-01  408-1008226-2450750       Expedited
# 4 2022-04-01  403-4108307-0229121       Expedited
#
#                          status fulfilment courier_status category    style  \
# 0  Shipped - Delivered to Buyer   Merchant        Shipped    Kurta  JNE3724
# 1                       Shipped     Amazon        Shipped      Set   SET187
# 2                     Cancelled   Merchant      Unshipped    Kurta  JNE3383
# 3                       Shipped     Amazon        Shipped    Kurta  JNE3405
# 4                       Shipped     Amazon        Shipped      Set   SET044
#
#                sku size  ...        state  postal_code latitude longitude  \
# 0     JNE3724-KR-L    L  ...  West Bengal       700124  22.4656   88.7803
# 1  SET187-KR-DH-XL   XL  ...    Karnataka       560090  13.2257   77.5750
# 2   JNE3383-KR-A-M    M  ...      Haryana       122001  28.4180   76.9839
# 3     JNE3405-KR-L    L  ...  Maharashtra       401209  19.3600   73.3279
# 4   SET044-KR-NP-L    L  ...    Telangana       500024  17.4171   78.4772
#
#                      promo_id fulfilled_by    b2b  has_amount status_clean  \
# 0  Amazon PLCC Free-Financing    Easy Ship  False        True      Shipped
# 1                        None        Other  False        True      Shipped
# 2                        None    Easy Ship  False        True    Cancelled
# 3                        None        Other  False        True      Shipped
# 4                        None        Other  False        True      Shipped
#
#   status_mismatch
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#
# [5 rows x 24 columns]

# %%
df_amazon_sr_paid.groupby(['status_clean', 'courier_status']).size().unstack(fill_value=0)
# Out:
# courier_status         Shipped  Unshipped
# status_clean
# Pending                     10        927
# Returned                  2103          0
# Shipped                 105077          0
# Shipped - Replacement     2262          0

# %%
# Tag weird rows with new column status_mismatch
df_amazon_sr_paid['status_mismatch'] = (
        ((df_amazon_sr_paid['status_clean'] == 'Pending') & (df_amazon_sr_paid['courier_status'] == 'Shipped'))
)
df_amazon_sr_paid.head()
# Out:
#         date             order_id shipping_method  \
# 0 2022-04-01  404-1445673-1345134        Standard
# 1 2022-04-01  406-7387241-2881923       Expedited
# 3 2022-04-01  408-1008226-2450750       Expedited
# 4 2022-04-01  403-4108307-0229121       Expedited
# 8 2022-04-01  406-1810033-9165961       Expedited
#
#                          status fulfilment courier_status category    style  \
# 0  Shipped - Delivered to Buyer   Merchant        Shipped    Kurta  JNE3724
# 1                       Shipped     Amazon        Shipped      Set   SET187
# 3                       Shipped     Amazon        Shipped    Kurta  JNE3405
# 4                       Shipped     Amazon        Shipped      Set   SET044
# 8                       Shipped     Amazon        Shipped      Set    J0345
#
#                sku size  ...        state  postal_code latitude longitude  \
# 0     JNE3724-KR-L    L  ...  West Bengal       700124  22.4656   88.7803
# 1  SET187-KR-DH-XL   XL  ...    Karnataka       560090  13.2257   77.5750
# 3     JNE3405-KR-L    L  ...  Maharashtra       401209  19.3600   73.3279
# 4   SET044-KR-NP-L    L  ...    Telangana       500024  17.4171   78.4772
# 8      J0345-SET-M    M  ...    Karnataka       560085  13.2257   77.5750
#
#                      promo_id fulfilled_by    b2b  has_amount status_clean  \
# 0  Amazon PLCC Free-Financing    Easy Ship  False        True      Shipped
# 1                        None        Other  False        True      Shipped
# 3                        None        Other  False        True      Shipped
# 4                        None        Other  False        True      Shipped
# 8                        None        Other  False        True      Shipped
#
#   status_mismatch
# 0           False
# 1           False
# 3           False
# 4           False
# 8           False
#
# [5 rows x 24 columns]

# %%
# Check both dataframes: 
# df_amazon_sr should have null values only for currency/amount and lat/lon
# df_amazon_sr_paid should only have null for lat/lon

# %%
df_amazon_sr.isnull().sum()
# Out:
# date                  0
# order_id              0
# shipping_method       0
# status                0
# fulfilment            0
# courier_status        0
# category              0
# style                 0
# sku                   0
# size                  0
# qty                   0
# amount             7559
# currency           7559
# city                  0
# state                 0
# postal_code           0
# latitude           1172
# longitude          1172
# promo_id              0
# fulfilled_by          0
# b2b                   0
# has_amount            0
# status_clean          0
# status_mismatch       0
# dtype: int64

# %%
df_amazon_sr_paid.isnull().sum()
# Out:
# date                  0
# order_id              0
# shipping_method       0
# status                0
# fulfilment            0
# courier_status        0
# category              0
# style                 0
# sku                   0
# size                  0
# qty                   0
# amount                0
# currency              0
# city                  0
# state                 0
# postal_code           0
# latitude           1024
# longitude          1024
# promo_id              0
# fulfilled_by          0
# b2b                   0
# has_amount            0
# status_clean          0
# status_mismatch       0
# dtype: int64

# %%
# Cleaning done! Reset the indexes. 
# Reset the index so it starts at 0 and removes the old index completely
df_amazon_sr.reset_index(drop=True, inplace=True)
# Reset the index so it starts at 0 and removes the old index completely
df_amazon_sr_paid.reset_index(drop=True, inplace=True)

# %%
# Inspect the final clean versions!

# %%
df_amazon_sr.describe()
# Out:
#                                 date            qty         amount  \
# count                         128699  128699.000000  121140.000000
# mean   2022-05-13 11:52:27.856626432       0.904786     648.573876
# min              2022-04-01 00:00:00       0.000000       0.000000
# 25%              2022-04-21 00:00:00       1.000000     449.000000
# 50%              2022-05-11 00:00:00       1.000000     605.000000
# 75%              2022-06-05 00:00:00       1.000000     788.000000
# max              2022-06-30 00:00:00       8.000000    5584.000000
# std                              NaN       0.307121     281.208949
#
#             latitude      longitude
# count  127527.000000  127527.000000
# mean       19.841107      78.274407
# min         8.099100      68.757400
# 25%        13.225700      75.763300
# 50%        18.980800      77.575000
# 75%        25.597700      79.810700
# max        34.531900      96.195200
# std         6.228809       4.416596

# %%
df_amazon_sr_paid.describe()
# Out:
#                                 date            qty         amount  \
# count                         110379  110379.000000  110379.000000
# mean   2022-05-13 14:03:15.102329344       1.003733     649.136022
# min              2022-04-01 00:00:00       1.000000       0.000000
# 25%              2022-04-21 00:00:00       1.000000     449.000000
# 50%              2022-05-11 00:00:00       1.000000     606.000000
# 75%              2022-06-05 00:00:00       1.000000     788.000000
# max              2022-06-30 00:00:00       8.000000    5584.000000
# std                              NaN       0.072892     283.205182
#
#             latitude      longitude
# count  109355.000000  109355.000000
# mean       19.847478      78.248877
# min         8.099100      68.757400
# 25%        13.225700      75.762800
# 50%        18.980800      77.575000
# 75%        25.599000      79.777300
# max        34.531900      96.195200
# std         6.219281       4.410860

# %%
df_amazon_sr.head()
# Out:
#         date             order_id shipping_method  \
# 0 2022-04-01  404-1445673-1345134        Standard
# 1 2022-04-01  406-7387241-2881923       Expedited
# 2 2022-04-01  402-9332104-0945115        Standard
# 3 2022-04-01  408-1008226-2450750       Expedited
# 4 2022-04-01  403-4108307-0229121       Expedited
#
#                          status fulfilment courier_status category    style  \
# 0  Shipped - Delivered to Buyer   Merchant        Shipped    Kurta  JNE3724
# 1                       Shipped     Amazon        Shipped      Set   SET187
# 2                     Cancelled   Merchant      Unshipped    Kurta  JNE3383
# 3                       Shipped     Amazon        Shipped    Kurta  JNE3405
# 4                       Shipped     Amazon        Shipped      Set   SET044
#
#                sku size  ...        state  postal_code latitude longitude  \
# 0     JNE3724-KR-L    L  ...  West Bengal       700124  22.4656   88.7803
# 1  SET187-KR-DH-XL   XL  ...    Karnataka       560090  13.2257   77.5750
# 2   JNE3383-KR-A-M    M  ...      Haryana       122001  28.4180   76.9839
# 3     JNE3405-KR-L    L  ...  Maharashtra       401209  19.3600   73.3279
# 4   SET044-KR-NP-L    L  ...    Telangana       500024  17.4171   78.4772
#
#                      promo_id fulfilled_by    b2b  has_amount status_clean  \
# 0  Amazon PLCC Free-Financing    Easy Ship  False        True      Shipped
# 1                        None        Other  False        True      Shipped
# 2                        None    Easy Ship  False        True    Cancelled
# 3                        None        Other  False        True      Shipped
# 4                        None        Other  False        True      Shipped
#
#   status_mismatch
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#
# [5 rows x 24 columns]

# %%
df_amazon_sr_paid.head()
# Out:
#         date             order_id shipping_method  \
# 0 2022-04-01  404-1445673-1345134        Standard
# 1 2022-04-01  406-7387241-2881923       Expedited
# 2 2022-04-01  408-1008226-2450750       Expedited
# 3 2022-04-01  403-4108307-0229121       Expedited
# 4 2022-04-01  406-1810033-9165961       Expedited
#
#                          status fulfilment courier_status category    style  \
# 0  Shipped - Delivered to Buyer   Merchant        Shipped    Kurta  JNE3724
# 1                       Shipped     Amazon        Shipped      Set   SET187
# 2                       Shipped     Amazon        Shipped    Kurta  JNE3405
# 3                       Shipped     Amazon        Shipped      Set   SET044
# 4                       Shipped     Amazon        Shipped      Set    J0345
#
#                sku size  ...        state  postal_code latitude longitude  \
# 0     JNE3724-KR-L    L  ...  West Bengal       700124  22.4656   88.7803
# 1  SET187-KR-DH-XL   XL  ...    Karnataka       560090  13.2257   77.5750
# 2     JNE3405-KR-L    L  ...  Maharashtra       401209  19.3600   73.3279
# 3   SET044-KR-NP-L    L  ...    Telangana       500024  17.4171   78.4772
# 4      J0345-SET-M    M  ...    Karnataka       560085  13.2257   77.5750
#
#                      promo_id fulfilled_by    b2b  has_amount status_clean  \
# 0  Amazon PLCC Free-Financing    Easy Ship  False        True      Shipped
# 1                        None        Other  False        True      Shipped
# 2                        None        Other  False        True      Shipped
# 3                        None        Other  False        True      Shipped
# 4                        None        Other  False        True      Shipped
#
#   status_mismatch
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#
# [5 rows x 24 columns]

# %%
# We will use df_amazon_sr_paid for financial analysis (real, completed sales only)

# %%
# For SKU-level or category-level trend analysis, sales volume, promo use, and time-based visualizations,
# we'll create a new version (df_amazon_sr_mean) with missing 'amount' values filled using the mean price per SKU

df_amazon_sr_mean = df_amazon_sr.copy()

# Flag rows where 'amount' was originally missing (for transparency in analysis)
df_amazon_sr_mean['amount_filled'] = df_amazon_sr_mean['amount'].isnull()

# Build a mapping of SKU -> average amount
sku_mean_map = (
    df_amazon_sr_mean.groupby('sku')['amount']
    .mean()
    .to_dict()
)

# Fill missing 'amount' values using the SKU-level mean
df_amazon_sr_mean['amount'] = df_amazon_sr_mean['amount'].fillna(
    df_amazon_sr_mean['sku'].map(sku_mean_map)
)

# Fill any remaining missing currency values with 'INR'
df_amazon_sr_mean['currency'] = df_amazon_sr_mean['currency'].fillna('INR')

# %%
# Check null values, should be none (except lat/lon)
df_amazon_sr_mean.isnull().sum()
# Out:
# date                  0
# order_id              0
# shipping_method       0
# status                0
# fulfilment            0
# courier_status        0
# category              0
# style                 0
# sku                   0
# size                  0
# qty                   0
# amount               34
# currency              0
# city                  0
# state                 0
# postal_code           0
# latitude           1172
# longitude          1172
# promo_id              0
# fulfilled_by          0
# b2b                   0
# has_amount            0
# status_clean          0
# status_mismatch       0
# amount_filled         0
# dtype: int64

# %%
# Inspect the 34 skus with null values for amount
df_amazon_sr_mean[df_amazon_sr_mean['amount'].isnull()]['sku'].value_counts()
# Out:
# sku
# BTM002-B-XXL          4
# J0184-KR-A-L          2
# SET226-KR-PP-L        2
# BL100-XXL             2
# J0086-DR-XL           1
# JNE3557-KR-XL         1
# J0024-KR-XXXL         1
# J0155-KR-XS           1
# J0250-SKD-XS          1
# JNE3364-KR-1051-XS    1
# SET083-KR-PP-L        1
# SET043-KR-NP-XXL      1
# JNE2294-KR-A-XS       1
# JNE3780-KR-XS         1
# BL091-XL              1
# JNE3662-TP-M          1
# JNE3447-KR-XL         1
# J0034-SET-S           1
# JNE2145-KR-A-L        1
# JNE3483-KR-M          1
# JNE3403-KR-XXL        1
# SAR182                1
# JNE3897-KR-M          1
# J0073-KR-S            1
# JNE3891-TP-XXL        1
# SAR060                1
# JNE3909-KR-L          1
# J0374-KR-M            1
# Name: count, dtype: int64

# %%
# Drop 34 remaining rows where 'amount' could not be calculated (no valid price history for the sku)
df_amazon_sr_mean = df_amazon_sr_mean[df_amazon_sr_mean['amount'].notna()]

# %%
# Final check
df_amazon_sr_mean.isnull().sum()
# Out:
# date                  0
# order_id              0
# shipping_method       0
# status                0
# fulfilment            0
# courier_status        0
# category              0
# style                 0
# sku                   0
# size                  0
# qty                   0
# amount                0
# currency              0
# city                  0
# state                 0
# postal_code           0
# latitude           1171
# longitude          1171
# promo_id              0
# fulfilled_by          0
# b2b                   0
# has_amount            0
# status_clean          0
# status_mismatch       0
# amount_filled         0
# dtype: int64

# %%
# Apply same function for the 'status' column to add clean 'order_status' column
df_amazon_sr_mean['status_clean'] = df_amazon_sr_mean.apply(
    lambda row: clean_order_status(row['status'], row['amount']),
    axis=1
)

# %%
df_amazon_sr_paid.groupby(['status_clean', 'courier_status']).size().unstack(fill_value=0)
# Out:
# courier_status         Shipped  Unshipped
# status_clean
# Pending                     10        927
# Returned                  2103          0
# Shipped                 105077          0
# Shipped - Replacement     2262          0

# %%
# Tag weird rows with new column status_mismatch
df_amazon_sr_mean['status_mismatch'] = (
    ((df_amazon_sr_mean['status_clean'] == 'Pending') & (df_amazon_sr_mean['courier_status'] == 'Shipped'))
)
df_amazon_sr_mean.head()
# Out:
#         date             order_id shipping_method  \
# 0 2022-04-01  404-1445673-1345134        Standard
# 1 2022-04-01  406-7387241-2881923       Expedited
# 2 2022-04-01  402-9332104-0945115        Standard
# 3 2022-04-01  408-1008226-2450750       Expedited
# 4 2022-04-01  403-4108307-0229121       Expedited
#
#                          status fulfilment courier_status category    style  \
# 0  Shipped - Delivered to Buyer   Merchant        Shipped    Kurta  JNE3724
# 1                       Shipped     Amazon        Shipped      Set   SET187
# 2                     Cancelled   Merchant      Unshipped    Kurta  JNE3383
# 3                       Shipped     Amazon        Shipped    Kurta  JNE3405
# 4                       Shipped     Amazon        Shipped      Set   SET044
#
#                sku size  ...  postal_code  latitude longitude  \
# 0     JNE3724-KR-L    L  ...       700124   22.4656   88.7803
# 1  SET187-KR-DH-XL   XL  ...       560090   13.2257   77.5750
# 2   JNE3383-KR-A-M    M  ...       122001   28.4180   76.9839
# 3     JNE3405-KR-L    L  ...       401209   19.3600   73.3279
# 4   SET044-KR-NP-L    L  ...       500024   17.4171   78.4772
#
#                      promo_id fulfilled_by    b2b  has_amount  status_clean  \
# 0  Amazon PLCC Free-Financing    Easy Ship  False        True       Shipped
# 1                        None        Other  False        True       Shipped
# 2                        None    Easy Ship  False        True     Cancelled
# 3                        None        Other  False        True       Shipped
# 4                        None        Other  False        True       Shipped
#
#   status_mismatch amount_filled
# 0           False         False
# 1           False         False
# 2           False         False
# 3           False         False
# 4           False         False
#
# [5 rows x 25 columns]

# %%
# Reset the index so it starts at 0 and removes the old index completely
df_amazon_sr_mean.reset_index(drop=True, inplace=True)

# %%
# Confirm shape for each data frame
print ('df_amazon_sr',df_amazon_sr.shape)
print('df_amazon_sr_paid', df_amazon_sr_paid.shape)
print('df_amazon_sr_mean', df_amazon_sr_mean.shape)
# Out:
# df_amazon_sr (128699, 24)
# df_amazon_sr_paid (110379, 24)
# df_amazon_sr_mean (128665, 25)

# %%
# Dataframes are clean but there are category mismatches with cleaned sale_report.csv

# %%
# Load in the dataframe to compare

df_sr = pd.read_csv('../cleaned_data/sale_report.csv')

# %%
# Merge on sku to compare category values
df_compare = df_amazon_sr.merge(
    df_sr,
    how='inner',
    on='sku',
    suffixes=('_amazon', '_sr')
)
df_compare.head()
# Out:
#         date             order_id shipping_method  \
# 0 2022-04-01  404-1445673-1345134        Standard
# 1 2022-04-01  406-7387241-2881923       Expedited
# 2 2022-04-01  408-1008226-2450750       Expedited
# 3 2022-04-01  403-4108307-0229121       Expedited
# 4 2022-04-01  407-0339645-8708348        Standard
#
#                          status fulfilment courier_status category_amazon  \
# 0  Shipped - Delivered to Buyer   Merchant        Shipped           Kurta
# 1                       Shipped     Amazon        Shipped             Set
# 2                       Shipped     Amazon        Shipped           Kurta
# 3                       Shipped     Amazon        Shipped             Set
# 4                     Cancelled   Merchant      Unshipped   Western Dress
#
#      style              sku size_amazon  ...  fulfilled_by    b2b has_amount  \
# 0  JNE3724     JNE3724-KR-L           L  ...     Easy Ship  False       True
# 1   SET187  SET187-KR-DH-XL          XL  ...         Other  False       True
# 2  JNE3405     JNE3405-KR-L           L  ...         Other  False       True
# 3   SET044   SET044-KR-NP-L           L  ...         Other  False       True
# 4  JNE3797     JNE3797-KR-L           L  ...     Easy Ship  False       True
#
#   status_clean status_mismatch design_no  stock  category_sr size_sr    color
# 0      Shipped           False   JNE3724      8        Kurta       L     Pink
# 1      Shipped           False    SET187     71    Kurta Set      XL    Peach
# 2      Shipped           False   JNE3405    446        Kurta       L     Pink
# 3      Shipped           False    SET044     19    Kurta Set       L  Mustard
# 4    Cancelled           False   JNE3797      5    Kurta Set       L    Green
#
# [5 rows x 29 columns]

# %%
# Keep only rows where the category values don’t match between the two sources
df_disparities = df_compare[
    df_compare['category_amazon'] != df_compare['category_sr']
].copy()

# Drop duplicates based on style and source categories -— no need for every size/color variant
df_disparities_unique = df_disparities.drop_duplicates(
    subset=['style', 'design_no', 'category_amazon', 'category_sr']
)
df_disparities_unique.head()
# Out:
#         date             order_id shipping_method     status fulfilment  \
# 1 2022-04-01  406-7387241-2881923       Expedited    Shipped     Amazon
# 3 2022-04-01  403-4108307-0229121       Expedited    Shipped     Amazon
# 4 2022-04-01  407-0339645-8708348        Standard  Cancelled   Merchant
# 5 2022-04-01  171-1556000-8993931       Expedited  Cancelled     Amazon
# 6 2022-04-01  403-9536559-5724368       Expedited  Cancelled     Amazon
#
#   courier_status category_amazon    style                sku size_amazon  ...  \
# 1        Shipped             Set   SET187    SET187-KR-DH-XL          XL  ...
# 3        Shipped             Set   SET044     SET044-KR-NP-L           L  ...
# 4      Unshipped   Western Dress  JNE3797       JNE3797-KR-L           L  ...
# 5      Cancelled             Set   SET282  SET282-KR-PP-XXXL         3XL  ...
# 6      Cancelled             Set   SET327    SET327-KR-DPT-L           L  ...
#
#    fulfilled_by    b2b has_amount status_clean status_mismatch design_no  \
# 1         Other  False       True      Shipped           False    SET187
# 3         Other  False       True      Shipped           False    SET044
# 4     Easy Ship  False       True    Cancelled           False   JNE3797
# 5         Other  False      False    Cancelled           False    SET282
# 6         Other  False      False    Cancelled           False    SET327
#
#    stock  category_sr size_sr    color
# 1     71    Kurta Set      XL    Peach
# 3     19    Kurta Set       L  Mustard
# 4      5    Kurta Set       L    Green
# 5      0    Kurta Set     3XL   Yellow
# 6     12    Kurta Set       L    Black
#
# [5 rows x 29 columns]

# %%
# Pull just the columns I want/need to review and correct — cleaner to work with in excel
df_export = df_disparities_unique[[
    'sku', 'style', 'category_amazon', 'design_no', 'category_sr'
]]

# %%
# Make a safe copy so I can add a column (without pandas throwing warnings)
df_export = df_export.copy()
df_export['correct_category'] = ''

# %%
# Save to csv to work on in excel
df_export.to_csv('../data/category_disparities.csv', index=False)

# %%
# Import csv with category_fixed filled
df_fixes = pd.read_csv('../data/category_disparities_fixed.csv')

# %%
# Create a style -> correct_category map
fix_map = dict(zip(df_fixes['style'], df_fixes['correct_category']))

# %%
# Update category only where I’ve provided a correction — keep the original if it’s not in the fix map
df_amazon_sr['category'] = df_amazon_sr.apply(
    lambda row: fix_map[row['style']] if row['style'] in fix_map else row['category'],
    axis=1
)

# %%
# Check - as expected, can see both updated styles and old ones
df_amazon_sr.head(10)
# Out:
#         date             order_id shipping_method  \
# 0 2022-04-01  404-1445673-1345134        Standard
# 1 2022-04-01  406-7387241-2881923       Expedited
# 2 2022-04-01  402-9332104-0945115        Standard
# 3 2022-04-01  408-1008226-2450750       Expedited
# 4 2022-04-01  403-4108307-0229121       Expedited
# 5 2022-04-01  407-0339645-8708348        Standard
# 6 2022-04-01  171-1556000-8993931       Expedited
# 7 2022-04-01  403-9536559-5724368       Expedited
# 8 2022-04-01  406-1810033-9165961       Expedited
# 9 2022-04-01  407-3386003-0476346       Expedited
#
#                          status fulfilment courier_status   category    style  \
# 0  Shipped - Delivered to Buyer   Merchant        Shipped      Kurta  JNE3724
# 1                       Shipped     Amazon        Shipped  Kurta Set   SET187
# 2                     Cancelled   Merchant      Unshipped      Kurta  JNE3383
# 3                       Shipped     Amazon        Shipped      Kurta  JNE3405
# 4                       Shipped     Amazon        Shipped  Kurta Set   SET044
# 5                     Cancelled   Merchant      Unshipped  Kurta Set  JNE3797
# 6                     Cancelled     Amazon      Cancelled  Kurta Set   SET282
# 7                     Cancelled     Amazon      Cancelled        Set   SET327
# 8                       Shipped     Amazon        Shipped        Set    J0345
# 9                       Shipped     Amazon        Shipped        Set   SET366
#
#                  sku size  ...        state  postal_code latitude longitude  \
# 0       JNE3724-KR-L    L  ...  West Bengal       700124  22.4656   88.7803
# 1    SET187-KR-DH-XL   XL  ...    Karnataka       560090  13.2257   77.5750
# 2     JNE3383-KR-A-M    M  ...      Haryana       122001  28.4180   76.9839
# 3       JNE3405-KR-L    L  ...  Maharashtra       401209  19.3600   73.3279
# 4     SET044-KR-NP-L    L  ...    Telangana       500024  17.4171   78.4772
# 5       JNE3797-KR-L    L  ...       Kerala       673101  11.6103   75.7806
# 6  SET282-KR-PP-XXXL  3XL  ...  West Bengal       700029  22.5553   88.3558
# 7    SET327-KR-DPT-L    L  ...    Telangana       500020  17.4057   78.4944
# 8        J0345-SET-M    M  ...    Karnataka       560085  13.2257   77.5750
# 9     SET366-KR-NP-S    S  ...  Maharashtra       421302  19.2166   73.2176
#
#                      promo_id fulfilled_by    b2b  has_amount status_clean  \
# 0  Amazon PLCC Free-Financing    Easy Ship  False        True      Shipped
# 1                        None        Other  False        True      Shipped
# 2                        None    Easy Ship  False        True    Cancelled
# 3                        None        Other  False        True      Shipped
# 4                        None        Other  False        True      Shipped
# 5                        None    Easy Ship  False        True    Cancelled
# 6                        None        Other  False       False    Cancelled
# 7                        None        Other  False       False    Cancelled
# 8                        None        Other  False        True      Shipped
# 9                        None        Other  False        True      Shipped
#
#   status_mismatch
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# 5           False
# 6           False
# 7           False
# 8           False
# 9           False
#
# [10 rows x 24 columns]

# %%
# Check out the value counts
df_amazon_sr['category'].value_counts()
# Out:
# category
# Kurta                    49754
# Kurta Set                38645
# Set                      14309
# Western Dress             9385
# Top                       8936
# Night Wear                2313
# Tunic                     1453
# Ethnic Dress              1158
# Blouse                     922
# Crop Top With Palazzo      498
# Lehenga Choli              484
# Crop Top                   201
# Palazzo                    187
# Saree                      164
# Leggings                   124
# Pant                       122
# Cardigan                    20
# Jumpsuit                    15
# Bottom                       6
# Dupatta                      3
# Name: count, dtype: int64

# %%
# Categories are cleaner. The remaing Sets are likely Kurta Set; 
# Tops are either Tunic, Blouse, or Crop Top, 
# Bottoms are either Palazzo, Leggings, or Pants

# %%
# The sku for Kurta Sets have either 'KR', 'SET' or 'SKD' 
# We should catch them all here:

mask_set_kr_set_skd = (
    (df_amazon_sr['category'] == 'Set') &
    (df_amazon_sr['sku'].str.contains('KR|SET|SKD', na=False))
)
df_amazon_sr.loc[mask_set_kr_set_skd, 'category'] = 'Kurta Set'

# %%
# Check - got them all!
df_amazon_sr['category'].value_counts()
# Out:
# category
# Kurta Set                52954
# Kurta                    49754
# Western Dress             9385
# Top                       8936
# Night Wear                2313
# Tunic                     1453
# Ethnic Dress              1158
# Blouse                     922
# Crop Top With Palazzo      498
# Lehenga Choli              484
# Crop Top                   201
# Palazzo                    187
# Saree                      164
# Leggings                   124
# Pant                       122
# Cardigan                    20
# Jumpsuit                    15
# Bottom                       6
# Dupatta                      3
# Name: count, dtype: int64

# %%
# The sku for Tunic contains TU
# The sku for Blouse contains BL
# The sku for Crop Top contains TP
# The sku for Cardigan contains CD
# Let's filter those Tops

mask_top_tu = (
    (df_amazon_sr['category'] == 'Top') &
    (df_amazon_sr['sku'].str.contains('TU', na=False))
)
df_amazon_sr.loc[mask_top_tu, 'category'] = 'Tunic'

mask_top_bl = (
    (df_amazon_sr['category'] == 'Top') &
    (df_amazon_sr['sku'].str.contains('BL', na=False))
)
df_amazon_sr.loc[mask_top_bl, 'category'] = 'Blouse'

mask_top_tp = (
    (df_amazon_sr['category'] == 'Top') &
    (df_amazon_sr['sku'].str.contains('TP', na=False))
)
df_amazon_sr.loc[mask_top_tp, 'category'] = 'Crop Top'

mask_top_cd = (
    (df_amazon_sr['category'] == 'Top') &
    (df_amazon_sr['sku'].str.contains('CD', na=False))
)
df_amazon_sr.loc[mask_top_cd, 'category'] = 'Cardigan'

# %%
df_amazon_sr['category'].value_counts()
# Got them all again :)
# Out:
# category
# Kurta Set                52954
# Kurta                    49754
# Western Dress             9385
# Crop Top                  8989
# Night Wear                2313
# Tunic                     1600
# Ethnic Dress              1158
# Blouse                     922
# Crop Top With Palazzo      498
# Lehenga Choli              484
# Palazzo                    187
# Saree                      164
# Leggings                   124
# Pant                       122
# Cardigan                    21
# Jumpsuit                    15
# Bottom                       6
# Dupatta                      3
# Name: count, dtype: int64

# %%
# Since there are only 6 Bottoms, let's have a look
df_amazon_sr[df_amazon_sr['category'] == 'Bottom']
# Out:
#             date             order_id shipping_method  \
# 32667 2022-04-21  403-6781808-5068367       Expedited
# 33870 2022-04-22  406-2345701-7973952       Expedited
# 39527 2022-04-25  408-6022939-2897110        Standard
# 41874 2022-04-27  407-4754304-8740360       Expedited
# 79455 2022-05-23  408-4686308-6807529        Standard
# 86896 2022-05-29  403-5414902-6244310       Expedited
#
#                              status fulfilment courier_status category  \
# 32667                       Shipped     Amazon        Shipped   Bottom
# 33870                       Shipped     Amazon        Shipped   Bottom
# 39527                       Shipped     Amazon        Shipped   Bottom
# 41874                       Shipped     Amazon        Shipped   Bottom
# 79455  Shipped - Delivered to Buyer   Merchant        Shipped   Bottom
# 86896                       Shipped     Amazon        Shipped   Bottom
#
#         style            sku size  ...        state  postal_code latitude  \
# 32667  BTM021    BTM021-B-XS   XS  ...  West Bengal       711106  22.5260
# 33870  BTM021     BTM021-B-L    L  ...  Maharashtra       400050  18.9808
# 39527  BTM021    BTM021-B-XS   XS  ...  West Bengal       711106  22.5260
# 41874  BTM021   BTM021-B-XXL  XXL  ...          Goa       403508  15.5945
# 79455  BTM004    BTM004-XXXL  3XL  ...        Delhi       110005  28.6551
# 86896  BTM021  BTM021-B-XXXL  3XL  ...   Tamil Nadu       600019  13.1582
#
#       longitude                    promo_id fulfilled_by    b2b  has_amount  \
# 32667   88.0676                        None        Other  False        True
# 33870   72.8338                        None        Other  False        True
# 39527   88.0676                        None        Other  False        True
# 41874   73.8682                        None        Other  False        True
# 79455   77.1833  Amazon PLCC Free-Financing    Easy Ship  False        True
# 86896   80.3018                        None        Other  False        True
#
#                 status_clean status_mismatch
# 32667                Shipped           False
# 33870                Shipped           False
# 39527  Shipped - Replacement           False
# 41874                Shipped           False
# 79455                Shipped           False
# 86896                Shipped           False
#
# [6 rows x 24 columns]

# %%
# The sku for Palazzo contains BTM + PP
# The sku for Leggings contains AN + a color
# The sku for Pants contains BTM + NP OR just BTM

# So the remaining bottoms are most likely pants

mask_bottom_btm = (
    (df_amazon_sr['category'] == 'Bottom') &
    (df_amazon_sr['sku'].str.contains('BTM', na=False))
)
df_amazon_sr.loc[mask_bottom_btm, 'category'] = 'Pant'

# %%
# Final check - we are clean
df_amazon_sr['category'].value_counts()
# Out:
# category
# Kurta Set                52954
# Kurta                    49754
# Western Dress             9385
# Crop Top                  8989
# Night Wear                2313
# Tunic                     1600
# Ethnic Dress              1158
# Blouse                     922
# Crop Top With Palazzo      498
# Lehenga Choli              484
# Palazzo                    187
# Saree                      164
# Pant                       128
# Leggings                   124
# Cardigan                    21
# Jumpsuit                    15
# Dupatta                      3
# Name: count, dtype: int64

# %%
# Build a fresh style -> category map from the cleaned df_amazon_sr
category_map = dict(zip(df_amazon_sr['style'], df_amazon_sr['category']))

# %%
# Use that to update categories in _paid & _mean dfs (fall back to existing category if something’s missing)
df_amazon_sr_paid['category'] = df_amazon_sr_paid.apply(
    lambda row: category_map.get(row['style'], row['category']),
    axis=1
)

df_amazon_sr_mean['category'] = df_amazon_sr_mean.apply(
    lambda row: category_map.get(row['style'], row['category']),
    axis=1
)

# %%
# Update df_sr using the cleaned categories from df_amazon_sr
# It helped break down 'Dress' into more specific types, and also fixed small stuff like typos and mislabels

category_fix_map = dict(zip(df_amazon_sr['style'], df_amazon_sr['category']))

# %%
df_sr['category'] = df_sr.apply(
    lambda row: category_fix_map[row['design_no']]
    if row['design_no'] in category_fix_map
    else row['category'],
    axis=1
)

# %%
# # Save the clean dataframes as new .csv files

# df_amazon_sr.to_csv('../cleaned_data/amazon_sales_full.csv', index=False)
# df_amazon_sr_paid.to_csv('../cleaned_data/amazon_sales_paid.csv', index=False)
# df_amazon_sr_mean.to_csv('../cleaned_data/amazon_sales_mean.csv', index=False)

# # Update sale_report.csv

# df_sr.to_csv('../cleaned_data/sale_report.csv', index=False)

# # index=False keeps the row numbers out of the file for cleaner for loading later

# %%
# This notebook cleaned the raw Amazon Sales Report CSV and produced three dataframes:
# 1. df_amazon_sr: full cleaned dataset (some included missing 'amount')
# 2. df_amazon_sr_paid: contains only valid, completed sales (non-cancelled + 'amount' present (use: financial analysis)
# 3. df_amazon_sr_mean: includes rows with filled 'amount'  using mean per sku (use: trend analysis)

# This notebook also updated df_sr to match categories
