# %%
import pandas as pd

# %%
df_sr = pd.read_csv(
    '../data/raw_csv_files/Sale Report.csv', low_memory=False)

# %%
df_sr.head()
# Out:
#    index       SKU Code Design No.  Stock       Category Size Color
# 0      0    AN201-RED-L      AN201    5.0  AN : LEGGINGS    L   Red
# 1      1    AN201-RED-M      AN201    5.0  AN : LEGGINGS    M   Red
# 2      2    AN201-RED-S      AN201    3.0  AN : LEGGINGS    S   Red
# 3      3   AN201-RED-XL      AN201    6.0  AN : LEGGINGS   XL   Red
# 4      4  AN201-RED-XXL      AN201    3.0  AN : LEGGINGS  XXL   Red

# %%
# Format columns
df_sr.columns = (
    df_sr.columns
    .str.strip()                                # Remove leading/trailing whitespace
    .str.lower()                                # Convert to lowercase
    .str.replace(r'[^\w\s]', '', regex=True)    # Remove special characters like - or .
    .str.replace(r'\s+', '_', regex=True)       # Replace spaces with underscores
)

# %%
df_sr.nunique()
# Out:
# index        9271
# sku_code     9170
# design_no    1594
# stock         295
# category       21
# size           11
# color          62
# dtype: int64

# %%
# Drop unnecessary index column
df_sr.drop(columns=['index'], inplace=True)

# %%
df_sr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9271 entries, 0 to 9270
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sku_code   9188 non-null   object
#  1   design_no  9235 non-null   object
#  2   stock      9235 non-null   float64
#  3   category   9226 non-null   object
#  4   size       9235 non-null   object
#  5   color      9226 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 434.7+ KB

# %%
# Change data type of 'Stock' to int and check
df_sr['stock'] = df_sr['stock'].fillna(0).astype(int)
df_sr['stock'].dtype
# Out:
# dtype('int64')

# %%
df_sr.head()
# Out:
#         sku_code design_no  stock       category size color
# 0    AN201-RED-L     AN201      5  AN : LEGGINGS    L   Red
# 1    AN201-RED-M     AN201      5  AN : LEGGINGS    M   Red
# 2    AN201-RED-S     AN201      3  AN : LEGGINGS    S   Red
# 3   AN201-RED-XL     AN201      6  AN : LEGGINGS   XL   Red
# 4  AN201-RED-XXL     AN201      3  AN : LEGGINGS  XXL   Red

# %%
# Rename sku_code columns to match other df columns
df_sr.rename(columns={'sku_code': 'sku'}, inplace=True)

# %%
df_sr['category'].unique().tolist()
# Out:
# ['AN : LEGGINGS',
#  'BLOUSE',
#  'PANT',
#  'BOTTOM',
#  'PALAZZO',
#  'SHARARA',
#  'SKIRT',
#  'DRESS',
#  'KURTA SET',
#  'LEHENGA CHOLI',
#  'SET',
#  'TOP',
#  'KURTA',
#  nan,
#  'CROP TOP',
#  'TUNIC',
#  'CARDIGAN',
#  'JUMPSUIT',
#  'CROP TOP WITH PLAZZO',
#  'SAREE',
#  'KURTI',
#  'NIGHT WEAR']

# %%
# Strip 'AN :' from any category values
df_sr['category'] = df_sr['category'].str.replace(r'^AN\s*:\s*', '', regex=True).str.strip()

# %%
# Format Title Case for category values to match other dataframes
df_sr['category'] = df_sr['category'].str.title()

# %%
# Check for duplicates
print(df_sr.duplicated().sum())
# Out:
# 38

# %%
# Inspect the 38 pairs of duplicates
dupes = df_sr[df_sr.duplicated(keep=False)]
display(dupes)
# Out:
#         sku design_no  stock category  size  color
# 83    #REF!     BL021      0   Blouse  FREE  Black
# 84    #REF!     BL021      0   Blouse  FREE  Black
# 86    #REF!     BL021      0   Blouse  FREE  Black
# 88    #REF!     BL022      0   Blouse  FREE  Beige
# 89    #REF!     BL022      0   Blouse  FREE  Beige
# 9235    NaN       NaN      0      NaN   NaN    NaN
# 9236    NaN       NaN      0      NaN   NaN    NaN
# 9237    NaN       NaN      0      NaN   NaN    NaN
# 9238    NaN       NaN      0      NaN   NaN    NaN
# 9239    NaN       NaN      0      NaN   NaN    NaN
# 9240    NaN       NaN      0      NaN   NaN    NaN
# 9241    NaN       NaN      0      NaN   NaN    NaN
# 9242    NaN       NaN      0      NaN   NaN    NaN
# 9243    NaN       NaN      0      NaN   NaN    NaN
# 9244    NaN       NaN      0      NaN   NaN    NaN
# 9245    NaN       NaN      0      NaN   NaN    NaN
# 9246    NaN       NaN      0      NaN   NaN    NaN
# 9247    NaN       NaN      0      NaN   NaN    NaN
# 9248    NaN       NaN      0      NaN   NaN    NaN
# 9249    NaN       NaN      0      NaN   NaN    NaN
# 9250    NaN       NaN      0      NaN   NaN    NaN
# 9251    NaN       NaN      0      NaN   NaN    NaN
# 9252    NaN       NaN      0      NaN   NaN    NaN
# 9253    NaN       NaN      0      NaN   NaN    NaN
# 9254    NaN       NaN      0      NaN   NaN    NaN
# 9255    NaN       NaN      0      NaN   NaN    NaN
# 9256    NaN       NaN      0      NaN   NaN    NaN
# 9257    NaN       NaN      0      NaN   NaN    NaN
# 9258    NaN       NaN      0      NaN   NaN    NaN
# 9259    NaN       NaN      0      NaN   NaN    NaN
# 9260    NaN       NaN      0      NaN   NaN    NaN
# 9261    NaN       NaN      0      NaN   NaN    NaN
# 9262    NaN       NaN      0      NaN   NaN    NaN
# 9263    NaN       NaN      0      NaN   NaN    NaN
# 9264    NaN       NaN      0      NaN   NaN    NaN
# 9265    NaN       NaN      0      NaN   NaN    NaN
# 9266    NaN       NaN      0      NaN   NaN    NaN
# 9267    NaN       NaN      0      NaN   NaN    NaN
# 9268    NaN       NaN      0      NaN   NaN    NaN
# 9269    NaN       NaN      0      NaN   NaN    NaN
# 9270    NaN       NaN      0      NaN   NaN    NaN

# %%
# Drop rows with '#REF!' in sku
df_sr = df_sr[df_sr['sku'] != '#REF!']

# Drop rows where all key columns are NaN
df_sr = df_sr.dropna(subset=['sku', 'design_no', 'category', 'size', 'color'], how='all')

# %%
df_sr.drop_duplicates(inplace=True)

# %%
# Check (should be empty dataframe now)
df_sr[df_sr['sku'] == '#REF!']
# Out:
# Empty DataFrame
# Columns: [sku, design_no, stock, category, size, color]
# Index: []

# %%
# Check duplicates now (should be 0)
print(df_sr.duplicated().sum())
# Out:
# 0

# %%
# Check for null values
df_sr.isnull().sum()
# Out:
# sku          47
# design_no     0
# stock         0
# category      9
# size          0
# color         9
# dtype: int64

# %%
# Check the sku nulls
df_sr[df_sr['sku'].isnull()]
# Out:
#       sku design_no  stock   category  size           color
# 135   NaN     BL086      1     Blouse  FREE            Blue
# 142   NaN     BL087      0     Blouse  FREE      Multicolor
# 197   NaN     BL097      1     Blouse  XXXL          Maroon
# 198   NaN     BL098      2     Blouse  FREE           Brown
# 223   NaN     BL102      1     Blouse  FREE       Navy Blue
# 248   NaN     BL109      2     Blouse  FREE            Gold
# 273   NaN     BL113      0     Blouse  XXXL          Maroon
# 546   NaN     CH203      0   Leggings  FREE          Maroon
# 901   NaN     J0055      0        NaN     S             NaN
# 902   NaN     J0055      0        NaN    XL             NaN
# 903   NaN     J0055      0        NaN    XS             NaN
# 904   NaN     J0055      0        NaN   XXL             NaN
# 938   NaN     J0071      0        NaN     S             NaN
# 939   NaN     J0071      0        NaN    XS             NaN
# 940   NaN     J0071      0        NaN  XXXL             NaN
# 1103  NaN     J0096      1      Kurta   4XL            Blue
# 1104  NaN     J0096      0      Kurta   5XL            Blue
# 1105  NaN     J0096      0      Kurta   6XL            Blue
# 2245  NaN     J0290      0   Cardigan  XXXL         Mustard
# 2537  NaN     J0342      0        Top  FREE            Blue
# 3306  NaN   JNE1906      1      Kurta   5XL           Black
# 3451  NaN   JNE2199      1      Kurta   6XL            Pink
# 3489  NaN   JNE2270      0      Kurta   6XL           Beige
# 3546  NaN   JNE3065      0      Kurta    XS  Turquoise Blue
# 3548  NaN   JNE3068      0      Kurta   5XL           Black
# 3549  NaN   JNE3068      0      Kurta   6XL           Black
# 3782  NaN   JNE3368      1      Kurta   6XL     Light Green
# 4001  NaN   JNE3421      0      Kurta   4XL            Grey
# 4002  NaN   JNE3421      0      Kurta   5XL            Grey
# 4003  NaN   JNE3421      0      Kurta   6XL            Grey
# 4017  NaN   JNE3423      0      Kurta   5XL           Black
# 4128  NaN   JNE3440      0      Kurta   5XL           White
# 4129  NaN   JNE3440      0      Kurta   6XL           White
# 4151  NaN   JNE3445      0      Kurta   5XL           White
# 4152  NaN   JNE3445      0      Kurta   6XL           White
# 4770  NaN   JNE3562      1      Kurta  XXXL           Peach
# 4804  NaN   JNE3568      0      Kurta   5XL          Yellow
# 5053  NaN   JNE3624      1      Kurta    XS           Taupe
# 5150  NaN   JNE3639      1        Top  XXXL          Maroon
# 5187  NaN   JNE3645      0        Top  XXXL             Red
# 5249  NaN   JNE3657      0        Top  XXXL           Black
# 5823  NaN   JNE3759      0      Kurta    XS            Pink
# 7247  NaN   PSET264      0        Set  XXXL            Gold
# 7482  NaN    SET058      1  Kurta Set   4XL            Teal
# 7593  NaN    SET111      0        NaN     M             NaN
# 7594  NaN    SET111      0        NaN  XXXL             NaN
# 8070  NaN    SET234      1  Kurta Set  XXXL           Green

# %%
# Define the rows with missing skus
df_sku_nulls = df_sr[df_sr['sku'].isnull()]

# Get the design_nos that have at least one non-null sku
designs_with_sku = df_sr[df_sr['sku'].notnull()]['design_no'].unique()

# Keep only rows where design_no exists elsewhere with a known sku
skus_to_fill = df_sku_nulls[df_sku_nulls['design_no'].isin(designs_with_sku)]
skus_to_fill
# Out:
#       sku design_no  stock   category  size           color
# 135   NaN     BL086      1     Blouse  FREE            Blue
# 142   NaN     BL087      0     Blouse  FREE      Multicolor
# 197   NaN     BL097      1     Blouse  XXXL          Maroon
# 198   NaN     BL098      2     Blouse  FREE           Brown
# 223   NaN     BL102      1     Blouse  FREE       Navy Blue
# 248   NaN     BL109      2     Blouse  FREE            Gold
# 273   NaN     BL113      0     Blouse  XXXL          Maroon
# 546   NaN     CH203      0   Leggings  FREE          Maroon
# 1103  NaN     J0096      1      Kurta   4XL            Blue
# 1104  NaN     J0096      0      Kurta   5XL            Blue
# 1105  NaN     J0096      0      Kurta   6XL            Blue
# 2245  NaN     J0290      0   Cardigan  XXXL         Mustard
# 2537  NaN     J0342      0        Top  FREE            Blue
# 3306  NaN   JNE1906      1      Kurta   5XL           Black
# 3451  NaN   JNE2199      1      Kurta   6XL            Pink
# 3489  NaN   JNE2270      0      Kurta   6XL           Beige
# 3546  NaN   JNE3065      0      Kurta    XS  Turquoise Blue
# 3548  NaN   JNE3068      0      Kurta   5XL           Black
# 3549  NaN   JNE3068      0      Kurta   6XL           Black
# 3782  NaN   JNE3368      1      Kurta   6XL     Light Green
# 4001  NaN   JNE3421      0      Kurta   4XL            Grey
# 4002  NaN   JNE3421      0      Kurta   5XL            Grey
# 4003  NaN   JNE3421      0      Kurta   6XL            Grey
# 4017  NaN   JNE3423      0      Kurta   5XL           Black
# 4128  NaN   JNE3440      0      Kurta   5XL           White
# 4129  NaN   JNE3440      0      Kurta   6XL           White
# 4151  NaN   JNE3445      0      Kurta   5XL           White
# 4152  NaN   JNE3445      0      Kurta   6XL           White
# 4770  NaN   JNE3562      1      Kurta  XXXL           Peach
# 4804  NaN   JNE3568      0      Kurta   5XL          Yellow
# 5053  NaN   JNE3624      1      Kurta    XS           Taupe
# 5150  NaN   JNE3639      1        Top  XXXL          Maroon
# 5187  NaN   JNE3645      0        Top  XXXL             Red
# 5249  NaN   JNE3657      0        Top  XXXL           Black
# 5823  NaN   JNE3759      0      Kurta    XS            Pink
# 7247  NaN   PSET264      0        Set  XXXL            Gold
# 7482  NaN    SET058      1  Kurta Set   4XL            Teal
# 8070  NaN    SET234      1  Kurta Set  XXXL           Green

# %%
# Filter out the rows where size = FREE
# The design_nos of these items don't have FREE as their size in the rest of the df
# Without the size, we can't impute the sku

skus_to_fill = skus_to_fill[skus_to_fill['size'] != 'FREE']
skus_to_fill
# Out:
#       sku design_no  stock   category  size           color
# 197   NaN     BL097      1     Blouse  XXXL          Maroon
# 273   NaN     BL113      0     Blouse  XXXL          Maroon
# 1103  NaN     J0096      1      Kurta   4XL            Blue
# 1104  NaN     J0096      0      Kurta   5XL            Blue
# 1105  NaN     J0096      0      Kurta   6XL            Blue
# 2245  NaN     J0290      0   Cardigan  XXXL         Mustard
# 3306  NaN   JNE1906      1      Kurta   5XL           Black
# 3451  NaN   JNE2199      1      Kurta   6XL            Pink
# 3489  NaN   JNE2270      0      Kurta   6XL           Beige
# 3546  NaN   JNE3065      0      Kurta    XS  Turquoise Blue
# 3548  NaN   JNE3068      0      Kurta   5XL           Black
# 3549  NaN   JNE3068      0      Kurta   6XL           Black
# 3782  NaN   JNE3368      1      Kurta   6XL     Light Green
# 4001  NaN   JNE3421      0      Kurta   4XL            Grey
# 4002  NaN   JNE3421      0      Kurta   5XL            Grey
# 4003  NaN   JNE3421      0      Kurta   6XL            Grey
# 4017  NaN   JNE3423      0      Kurta   5XL           Black
# 4128  NaN   JNE3440      0      Kurta   5XL           White
# 4129  NaN   JNE3440      0      Kurta   6XL           White
# 4151  NaN   JNE3445      0      Kurta   5XL           White
# 4152  NaN   JNE3445      0      Kurta   6XL           White
# 4770  NaN   JNE3562      1      Kurta  XXXL           Peach
# 4804  NaN   JNE3568      0      Kurta   5XL          Yellow
# 5053  NaN   JNE3624      1      Kurta    XS           Taupe
# 5150  NaN   JNE3639      1        Top  XXXL          Maroon
# 5187  NaN   JNE3645      0        Top  XXXL             Red
# 5249  NaN   JNE3657      0        Top  XXXL           Black
# 5823  NaN   JNE3759      0      Kurta    XS            Pink
# 7247  NaN   PSET264      0        Set  XXXL            Gold
# 7482  NaN    SET058      1  Kurta Set   4XL            Teal
# 8070  NaN    SET234      1  Kurta Set  XXXL           Green

# %%
# Make a loop to imput the missing skus 

# Get the rows with known skus
known_skus = df_sr[df_sr['sku'].notnull()]

# Build a lookup: design_no -> example sku
design_to_example_sku = known_skus.groupby('design_no')['sku'].first().to_dict()

# Loop through candidates, replace only the size part in the sku
adjusted_rows = []
for _, row in skus_to_fill.iterrows():
    design = row['design_no']
    size = row['size']
    
    # Get any known sku for this design_no
    example_sku = design_to_example_sku.get(design)

    # Skip if we don’t have any sku to copy from
    if not example_sku:
        continue

    # Skip if the known sku doesn’t follow the expected 'design-size' format
    # If there's no hyphen, we can't safely separate the size
    if '-' not in example_sku:
        continue
    
    # Replace the part after the last hyphen with the current row's size
    base = example_sku.rsplit('-', 1)[0]
    new_sku = f"{base}-{size}"
    
    # Make a copy of the row and update the sku
    new_row = row.copy()
    new_row['sku'] = new_sku
    adjusted_rows.append(new_row)

# Convert to df for inspection
adjusted_df = pd.DataFrame(adjusted_rows)
adjusted_df
# Out:
#                      sku design_no  stock   category  size           color
# 197           BL097-XXXL     BL097      1     Blouse  XXXL          Maroon
# 273           BL113-XXXL     BL113      0     Blouse  XXXL          Maroon
# 1103        J0096-KR-4XL     J0096      1      Kurta   4XL            Blue
# 1104        J0096-KR-5XL     J0096      0      Kurta   5XL            Blue
# 1105        J0096-KR-6XL     J0096      0      Kurta   6XL            Blue
# 2245       J0290-CD-XXXL     J0290      0   Cardigan  XXXL         Mustard
# 3306  JNE1906-KR-031-5XL   JNE1906      1      Kurta   5XL           Black
# 3451  JNE2199-KR-411-6XL   JNE2199      1      Kurta   6XL            Pink
# 3489  JNE2270-KR-487-6XL   JNE2270      0      Kurta   6XL           Beige
# 3546       JNE3065-KR-XS   JNE3065      0      Kurta    XS  Turquoise Blue
# 3548      JNE3068-KR-5XL   JNE3068      0      Kurta   5XL           Black
# 3549      JNE3068-KR-6XL   JNE3068      0      Kurta   6XL           Black
# 3782      JNE3368-KR-6XL   JNE3368      1      Kurta   6XL     Light Green
# 4001      JNE3421-KR-4XL   JNE3421      0      Kurta   4XL            Grey
# 4002      JNE3421-KR-5XL   JNE3421      0      Kurta   5XL            Grey
# 4003      JNE3421-KR-6XL   JNE3421      0      Kurta   6XL            Grey
# 4017      JNE3423-KR-5XL   JNE3423      0      Kurta   5XL           Black
# 4128      JNE3440-KR-5XL   JNE3440      0      Kurta   5XL           White
# 4129      JNE3440-KR-6XL   JNE3440      0      Kurta   6XL           White
# 4151      JNE3445-KR-5XL   JNE3445      0      Kurta   5XL           White
# 4152      JNE3445-KR-6XL   JNE3445      0      Kurta   6XL           White
# 4770     JNE3562-KR-XXXL   JNE3562      1      Kurta  XXXL           Peach
# 4804      JNE3568-KR-5XL   JNE3568      0      Kurta   5XL          Yellow
# 5053       JNE3624-KR-XS   JNE3624      1      Kurta    XS           Taupe
# 5150     JNE3639-TP-XXXL   JNE3639      1        Top  XXXL          Maroon
# 5187     JNE3645-TP-XXXL   JNE3645      0        Top  XXXL             Red
# 5249     JNE3657-TP-XXXL   JNE3657      0        Top  XXXL           Black
# 5823       JNE3759-KR-XS   JNE3759      0      Kurta    XS            Pink
# 7247  PSET264-KR-NP-XXXL   PSET264      0        Set  XXXL            Gold
# 7482    SET058-KR-NP-4XL    SET058      1  Kurta Set   4XL            Teal
# 8070   SET234-KR-PP-XXXL    SET234      1  Kurta Set  XXXL           Green

# %%
# Update using update (same index nos in both dfs) and confirm updated rows
df_sr.update(adjusted_df)
df_sr.loc[adjusted_df.index, ['design_no', 'size', 'sku']]
# Out:
#      design_no  size                 sku
# 197      BL097  XXXL          BL097-XXXL
# 273      BL113  XXXL          BL113-XXXL
# 1103     J0096   4XL        J0096-KR-4XL
# 1104     J0096   5XL        J0096-KR-5XL
# 1105     J0096   6XL        J0096-KR-6XL
# 2245     J0290  XXXL       J0290-CD-XXXL
# 3306   JNE1906   5XL  JNE1906-KR-031-5XL
# 3451   JNE2199   6XL  JNE2199-KR-411-6XL
# 3489   JNE2270   6XL  JNE2270-KR-487-6XL
# 3546   JNE3065    XS       JNE3065-KR-XS
# 3548   JNE3068   5XL      JNE3068-KR-5XL
# 3549   JNE3068   6XL      JNE3068-KR-6XL
# 3782   JNE3368   6XL      JNE3368-KR-6XL
# 4001   JNE3421   4XL      JNE3421-KR-4XL
# 4002   JNE3421   5XL      JNE3421-KR-5XL
# 4003   JNE3421   6XL      JNE3421-KR-6XL
# 4017   JNE3423   5XL      JNE3423-KR-5XL
# 4128   JNE3440   5XL      JNE3440-KR-5XL
# 4129   JNE3440   6XL      JNE3440-KR-6XL
# 4151   JNE3445   5XL      JNE3445-KR-5XL
# 4152   JNE3445   6XL      JNE3445-KR-6XL
# 4770   JNE3562  XXXL     JNE3562-KR-XXXL
# 4804   JNE3568   5XL      JNE3568-KR-5XL
# 5053   JNE3624    XS       JNE3624-KR-XS
# 5150   JNE3639  XXXL     JNE3639-TP-XXXL
# 5187   JNE3645  XXXL     JNE3645-TP-XXXL
# 5249   JNE3657  XXXL     JNE3657-TP-XXXL
# 5823   JNE3759    XS       JNE3759-KR-XS
# 7247   PSET264  XXXL  PSET264-KR-NP-XXXL
# 7482    SET058   4XL    SET058-KR-NP-4XL
# 8070    SET234  XXXL   SET234-KR-PP-XXXL

# %%
# Check reaming nulls
df_sr[df_sr['sku'].isnull()]
# Out:
#       sku design_no  stock  category  size       color
# 135   NaN     BL086      1    Blouse  FREE        Blue
# 142   NaN     BL087      0    Blouse  FREE  Multicolor
# 198   NaN     BL098      2    Blouse  FREE       Brown
# 223   NaN     BL102      1    Blouse  FREE   Navy Blue
# 248   NaN     BL109      2    Blouse  FREE        Gold
# 546   NaN     CH203      0  Leggings  FREE      Maroon
# 901   NaN     J0055      0       NaN     S         NaN
# 902   NaN     J0055      0       NaN    XL         NaN
# 903   NaN     J0055      0       NaN    XS         NaN
# 904   NaN     J0055      0       NaN   XXL         NaN
# 938   NaN     J0071      0       NaN     S         NaN
# 939   NaN     J0071      0       NaN    XS         NaN
# 940   NaN     J0071      0       NaN  XXXL         NaN
# 2537  NaN     J0342      0       Top  FREE        Blue
# 7593  NaN    SET111      0       NaN     M         NaN
# 7594  NaN    SET111      0       NaN  XXXL         NaN

# %%
# Drop remaining 16 rows with unrecoverable/null sku values
df_sr = df_sr[df_sr['sku'].notnull()]

# %%
df_sr.isnull().sum()
# Out:
# sku          0
# design_no    0
# stock        0
# category     0
# size         0
# color        0
# dtype: int64

# %%
# Check values for size
df_sr['size'].unique().tolist()
# Out:
# ['L', 'M', 'S', 'XL', 'XXL', 'FREE', 'XS', 'XXXL', '4XL', '5XL', '6XL']

# %%
# Change 'XXXL' to '3XL' for consistency in other datasets (all other are ok)
df_sr['size'] = df_sr['size'].replace('XXXL', '3XL')

# %%
# Check values for size
df_sr['size'].unique().tolist()
# Out:
# ['L', 'M', 'S', 'XL', 'XXL', 'FREE', 'XS', '3XL', '4XL', '5XL', '6XL']

# %%
df_sr.head()
# Out:
#              sku design_no  stock  category size color
# 0    AN201-RED-L     AN201      5  Leggings    L   Red
# 1    AN201-RED-M     AN201      5  Leggings    M   Red
# 2    AN201-RED-S     AN201      3  Leggings    S   Red
# 3   AN201-RED-XL     AN201      6  Leggings   XL   Red
# 4  AN201-RED-XXL     AN201      3  Leggings  XXL   Red

# %%
# Confirm shape for data frame
df_sr.shape
# Out:
# (9204, 6)

# %%
# !!! DO NOT RUN THIS UNLESS YOU ALSO RUN ITS UPDATED VERSION IN amazon_sale_report_dfs.ipynb !!!
# # Save the cleaned Sale Report to .csv
# df_sr.to_csv('../cleaned_data/sale_report.csv', index=False)
